# %% [markdown]
# # Assumptions
#
# * The total_paid must be greater or equal to the sum of product_quantity*sale_price for all orderlines in an order
# * regular_price must be greater or equal to sale_price
# * regular_price must be greater or equal to promo_price
# * promo_price could be less than sale_price if the product was sold at the regular_price
# * It is possible that the difference between the total_paid value and sum(product_quantity*sale_price) is the shipping cost

# %%
import re
import numpy as np
import pandas as pd
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

import data_utils
import price_debugging_tests as pdt

# Set maximum number of rows to display
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# # Import and merge data

# %%
# Import the data
orders = data_utils.clean_orders(data_path="../../data/")
orderlines = data_utils.clean_orderlines(data_path="../../data/")
products = data_utils.clean_products(data_path="../../data/")
brands = data_utils.clean_brands(data_path="../../data/")

# Merge the data
completed_sales =  data_utils.merge_data(orders, orderlines, products, brands)
# Out:
# 5 missing values were removed from orders.
# This represents 0.0022% of the data.
#
#
# 0 missing values were removed from orderlines.
# This represents 0.00% of the data.
#
#
# 8792 missing values were removed from products
# This represents 45.49% of the data.
#
#
# 0 missing values were removed from brands.
# This represents 0.00% of the data.

# %% [markdown]
# # Price data exploration
# ## Exclude orders with multiple orderlines and multiple products

# %%
# Get the count of orderlines per order from completed_sales
completed_sales_orderline_counts = completed_sales.groupby('order_id')['orderline_id'].count().reset_index()
completed_sales_orderline_counts.rename(columns={'orderline_id': 'orderline_count'}, inplace=True)

# Exclude orders with more than one orderline.
orders_with_one_orderline = completed_sales_orderline_counts[completed_sales_orderline_counts.orderline_count==1]
single_orderline_orders = completed_sales[completed_sales.order_id.isin(orders_with_one_orderline.order_id)]

# Exclude orders with product_quantity > 1
single_orderline_single_product = single_orderline_orders[single_orderline_orders.product_quantity==1].copy()
single_orderline_single_product.shape[0]/total_orders*100

print(f"We still have {np.round(single_orderline_single_product.shape[0]/total_orders*100)}% of the orders")
# Out:
# We still have 72.0% of the orders

# %% [markdown]
# ## Explore corrupted decimal values

# %% [markdown]
# ### Helper functions

# %%
def _calculate_percentage_difference(df, reference_col, comparison_col):
    return ((df[reference_col] - df[comparison_col])/df[reference_col]*100).round(2)

def add_discount_percentage_col(df):
    df['discount_percentage'] = _calculate_percentage_difference(df, 'regular_price', 'sale_price')
    return df

def check_for_outliers(df, reference_col='regular_price', comparison_col='sale_price'):
    ''' 
    Check for outliers to see if the decimal value is in the wrong spot. 
    
    We define an outlier as having a percentage difference between the two price 
    values greater than 3 standard deviations from the mean percentage difference.
    '''
    diff_col_name = comparison_col + '_vs_' + reference_col + '_percentage_diff'
    df[diff_col_name] = _calculate_percentage_difference(df, reference_col, comparison_col)
    
    mean_diff = df[diff_col_name].mean()
    std_diff = df[diff_col_name].std()
    threshold = mean_diff + 3 * std_diff
    
    outliers = df[abs(df[diff_col_name]) > threshold]
    
    return outliers

# %% [markdown]
# ## Evaluate potentially uncorrupted values

# %% [markdown]
# ### Decimal count = 1 = 1 = 1
# <div class="alert alert-box alert-info">
#     Since 67% of the total completed_sales data has total_paid_decimal_count = regular_price_decimal_count == sale_price_decimal_count == 1, cleaning this data will be a good first step.
# </div>

# %%
orderline_ids = single_orderline_single_product[
    (single_orderline_single_product.total_paid_decimal_count == 1) &
    (single_orderline_single_product.regular_price_decimal_count == 1) &
    (single_orderline_single_product.sale_price_decimal_count == 1)
].orderline_id

one_decimal_data = single_orderline_single_product[single_orderline_single_product.orderline_id.isin(orderline_ids)].copy()
one_decimal_data[['regular_price', 'sale_price']] = one_decimal_data[['regular_price', 'sale_price']].astype('float')
# drop the decimal count cols to clean up the output
one_decimal_data.drop(['total_paid_decimal_count', 'regular_price_decimal_count', 'sale_price_decimal_count'], axis=1, inplace=True)

# Add a discount percentage col to detect incorrect values and outliers
one_decimal_data = add_discount_percentage_col(one_decimal_data)

# %%
one_decimal_data[one_decimal_data.order_id==376743]
# Out:
#        order_id  orderline_id                date  \
# 19074    376743       1291409 2017-07-13 08:39:01
#
#                                                name  \
# 19074  5TB Lacie Rugged Hard Disk Thunderbolt USB-C
#
#                                                     desc  brand      sku  \
# 19074  5TB hard disk rugged, compact Thunderbolt and ...  LaCie  LAC0227
#
#       category  total_paid  product_quantity  regular_price  sale_price  \
# 19074   Memory      301.99                 1         299.99      301.99
#
#        discount_percentage
# 19074                -0.67

# %% [markdown]
# #### Problem 1: sale_price < total_paid

# %% [markdown]
# <div class="alert alert-box alert-danger">
#     There are cases where the sale_price is greater than the total_paid value.
# </div>

# %%
one_decimal_data[one_decimal_data.order_id.isin([301495, 281302, 274043, 287311, 300950, 296010, 297572])]
# Out:
#      order_id  orderline_id                date  \
# 92     274043       1121663 2017-01-02 16:30:49
# 111    281302       1142023 2017-01-12 01:00:05
# 131    287311       1164035 2017-01-29 22:54:50
# 160    296010       1138342 2017-01-09 23:41:57
# 182    297572       1162207 2017-01-27 23:53:16
# 684    300950       1122232 2017-01-02 20:20:08
# 866    301495       1123362 2017-01-03 12:04:16
#
#                                                   name  \
# 92   Griffin Magnetic BreakSafe-C USB charging cabl...
# 111                  Startech USB Adapter VGA-C Blanco
# 131           Sandisk iXpand Lightning to USB 3.0 64GB
# 160  Tucano Nido Hard-Shell Case MacBook Air 13 "Black
# 182  Twelve South BookArc support for MacBook Pro /...
# 684  Apple Mac mini Core i5 14GHz | 8GB RAM | 500GB...
# 866  Svolta Tucano MacBook Pro Sleeve bag / Retina ...
#
#                                                   desc         brand      sku  \
# 92   Charging cable and connector magnetic fast lib...       Griffin  GRT0425
# 111  Adapter with reversible USB connection VGA-C (...      Startech  STA0036
# 131              64GB storage unit for iPhone and iPad       SanDisk  SAN0134
# 160  rigid and slicked rubber feet MacBook Air 13 i...        Tucano  TUC0252
# 182     Aluminum support in an arc Retina MacBook Air.  Twelve South  TWS0093
# 684  Mac mini desktop computer 8GB RAM 500GB SSD (M...          Pack  PAC0594
# 866  compact case for MacBook / Air 13 and 13 inche...        Tucano  TUC0277
#
#         category  total_paid  product_quantity  regular_price  sale_price  \
# 92   Accessories        3.98                 1          34.99       24.99
# 111  Accessories       16.98                 1          53.99       29.99
# 131  Accessories       54.99                 1          69.99       59.99
# 160  Accessories        0.00                 1          29.90       24.99
# 182  Accessories       51.99                 1          59.99       56.99
# 684       Memory      777.99                 1        1135.59      782.99
# 866  Accessories        0.00                 1          29.90       24.99
#
#      discount_percentage
# 92                 28.58
# 111                44.45
# 131                14.29
# 160                16.42
# 182                 5.00
# 684                31.05
# 866                16.42

# %% [markdown]
# <div class="alert alert-box alert-danger">
#     The first case above seems to have the decimal point in the wrong place in total_paid.
#     <br><br>
#     Some of the prices are relatively similar, for example, the 3rd, 5th and 6th rows above, and could possibly be corrected by setting the total_paid equal to the sale_price.
#     <br><br>
#     Some of the data is too corrupted to be corrected: The 2nd, 4th and 7th rows.
# </div>

# %%
''' What percentage of the single_orderline_single_product data has total_paid values lower than the sale_price? '''
total_orders = one_decimal_data.shape[0]
sale_price_too_high = one_decimal_data[one_decimal_data.total_paid < one_decimal_data.sale_price].shape[0]
print(f"The sale_price is greater than the total_paid for {sale_price_too_high/total_orders*100:.2f}% of the orders. ")
# Out:
# The sale_price is greater than the total_paid for 0.68% of the orders.

# %% [markdown]
# <div class="alert alert-box alert-success">
#     This problem appears to apply to a very small percentage of the data and, for now, we will assume that the simplest way to deal with this problem is to delete these rows.
# </div>

# %% [markdown]
# #### Problem 2: regular_price < sale_price
#
# <div class="alert alert-box alert-danger">
#     There are orderlines where the regular_price is lower than the sale_price.
# </div>

# %%
one_decimal_data[one_decimal_data.order_id.isin([267375])]
# Out:
#     order_id  orderline_id                date  \
# 82    267375       1140087 2017-01-10 22:48:08
#
#                                                  name  \
# 82  Pure Nude Ultraslim 03 "7/8 Transparent iPhone...
#
#                                                  desc brand      sku  \
# 82  transparent and flexible cover with 03mm thick...  Puro  PUR0150
#
#        category  total_paid  product_quantity  regular_price  sale_price  \
# 82  Accessories       17.98                 1          12.95       12.99
#
#     discount_percentage
# 82                -0.31

# %%
''' What percentage of the data has regular_price values lower than the sale_price? '''
total_orders = one_decimal_data.shape[0]
sale_price_too_high = one_decimal_data[one_decimal_data.regular_price < one_decimal_data.sale_price].shape[0]
print(f"The sale_price is greater than the regular_price for {sale_price_too_high/total_orders*100:.2f}% of the orders. ")
# Out:
# The sale_price is greater than the regular_price for 3.30% of the orders.

# %%
''' 
It appears that for many of these cases the difference is minor, as seen above. 
Let's round the values and see if it makes a difference. 
'''

sale_price_greater_than_regular = one_decimal_data[one_decimal_data.regular_price < one_decimal_data.sale_price].copy()

sale_price_greater_than_regular.sale_price = sale_price_greater_than_regular.sale_price.round()
sale_price_greater_than_regular.regular_price = sale_price_greater_than_regular.regular_price.round()
sale_price_greater_than_regular.total_paid = sale_price_greater_than_regular.total_paid.round()

rounded_sale_price_too_high = sale_price_greater_than_regular[sale_price_greater_than_regular.regular_price < sale_price_greater_than_regular.sale_price].shape[0]
print(f"The sale_price is greater than the regular_price for {rounded_sale_price_too_high/total_orders*100:.2f}% of the orders. ")
# Out:
# The sale_price is greater than the regular_price for 1.18% of the orders.

# %%
'''
There are orderlines where there is a significant difference between the regular_price and sale_price.
It seems that the regular_price saved in products.csv has changed over time.
'''
sale_price_greater_than_regular[sale_price_greater_than_regular.regular_price < sale_price_greater_than_regular.sale_price].head()
# Out:
#      order_id  orderline_id                date  \
# 272    299829       1119702 2017-01-01 17:50:48
# 296    299909       1119872 2017-01-01 19:50:09
# 490    300464       1121064 2017-01-02 12:09:42
# 506    300497       1121164 2017-01-02 12:44:12
# 679    300941       1122210 2017-01-02 20:08:58
#
#                                                   name  \
# 272  LaCie Porsche Design Desktop Drive 8TB USB 3.0...
# 296  LaCie Porsche Design Desktop Drive 5TB USB 3.0...
# 490           Withings Activite Steel Black Dial White
# 506                        Full screen repair iPhone 5
# 679           Withings Activite Steel Black Dial White
#
#                                                   desc     brand      sku  \
# 272  External Hard Drive 8TB 35-inch USB 3.0 for Ma...     LaCie  LAC0171
# 296  External Hard Drive 5TB 35-inch USB 3.0 for Ma...     LaCie  LAC0159
# 490                    Smart Clock for iPhone and iPad  Withings  WIT0034
# 506  Repair service including parts and labor for i...    Repair  REP0134
# 679                    Smart Clock for iPhone and iPad  Withings  WIT0034
#
#                  category  total_paid  product_quantity  regular_price  \
# 272                Memory       282.0                 1          250.0
# 296                Memory       184.0                 1          175.0
# 490            Smartwatch       153.0                 1          130.0
# 506  Repairs & warranties       100.0                 1           60.0
# 679            Smartwatch       153.0                 1          130.0
#
#      sale_price  discount_percentage
# 272       275.0               -10.20
# 296       177.0                -0.97
# 490       153.0               -17.73
# 506        90.0               -50.01
# 679       153.0               -17.73

# %% [markdown]
# <div class="alert alert-box alert-success">
#     This solution seems to have worked relatively well.
#     <br><br>
#     It appears that for the remaining values the regular price has changed since the sale took place.
#     <br>
#     We will tackle that as the next problem.
# </div>

# %% [markdown]
# #### Problem 3: regular_price changing over time

# %% [markdown]
# <div class="alert alert-box alert-info">
#     We still have to solve the problem of the regular_price being less than the sale_price in some instances, so that the discount percentage can be calculated correctly.
#     <br>
#     Let's check the values above and see if the regular prices have changed over time.
# </div>

# %%
'''
LAC0159 - 16 rows, only the first value is incorrect. The sale_price is €1.70 greater than the regular_price
WIT0034 - 2 rows, total_paid = sale_price
REP0134 - 3 rows, total_paid = sale_price + 9.99 (shipping fee)
WIT0034 - 2 rows, total_paid = sale_price

LAC0171 - 108 rows, the first 6 rows have sale_price > regular_price. After that all the sale_prices are below the regular price, €249.99.
          However, the sale_price values in the first 6 rows (shown below) vary between €302.99 and €269.79.
          How do we know if €302.9 was the regular_price at this time and the other 5 values represent discount sales?
          The 4th, 5th and 6th rows have a sale_price of €283.99. 
          This could signify that the data is not corrupted but rather that this was a discount or a price change.
'''
sku = 'LAC0171'
completed_sales[completed_sales.sku.isin([sku])].sort_values('date').head(10)
# Out:
#        order_id  orderline_id                date  \
# 272      299829       1119702 2017-01-01 17:50:48
# 3085     308551       1143957 2017-01-13 10:00:40
# 6920     318532       1168266 2017-01-31 23:10:16
# 6970     318707       1168710 2017-02-01 10:38:02
# 7215     319407       1170172 2017-02-02 23:49:53
# 7218     319416       1170189 2017-02-03 00:34:15
# 12453    351854       1239836 2017-05-02 14:15:50
# 12476    351938       1240025 2017-05-02 18:17:42
# 12493    351987       1240131 2017-05-02 20:07:28
# 12682    352663       1241533 2017-05-04 14:00:16
#
#                                                     name  \
# 272    LaCie Porsche Design Desktop Drive 8TB USB 3.0...
# 3085   LaCie Porsche Design Desktop Drive 8TB USB 3.0...
# 6920   LaCie Porsche Design Desktop Drive 8TB USB 3.0...
# 6970   LaCie Porsche Design Desktop Drive 8TB USB 3.0...
# 7215   LaCie Porsche Design Desktop Drive 8TB USB 3.0...
# 7218   LaCie Porsche Design Desktop Drive 8TB USB 3.0...
# 12453  LaCie Porsche Design Desktop Drive 8TB USB 3.0...
# 12476  LaCie Porsche Design Desktop Drive 8TB USB 3.0...
# 12493  LaCie Porsche Design Desktop Drive 8TB USB 3.0...
# 12682  LaCie Porsche Design Desktop Drive 8TB USB 3.0...
#
#                                                     desc  brand      sku  \
# 272    External Hard Drive 8TB 35-inch USB 3.0 for Ma...  LaCie  LAC0171
# 3085   External Hard Drive 8TB 35-inch USB 3.0 for Ma...  LaCie  LAC0171
# 6920   External Hard Drive 8TB 35-inch USB 3.0 for Ma...  LaCie  LAC0171
# 6970   External Hard Drive 8TB 35-inch USB 3.0 for Ma...  LaCie  LAC0171
# 7215   External Hard Drive 8TB 35-inch USB 3.0 for Ma...  LaCie  LAC0171
# 7218   External Hard Drive 8TB 35-inch USB 3.0 for Ma...  LaCie  LAC0171
# 12453  External Hard Drive 8TB 35-inch USB 3.0 for Ma...  LaCie  LAC0171
# 12476  External Hard Drive 8TB 35-inch USB 3.0 for Ma...  LaCie  LAC0171
# 12493  External Hard Drive 8TB 35-inch USB 3.0 for Ma...  LaCie  LAC0171
# 12682  External Hard Drive 8TB 35-inch USB 3.0 for Ma...  LaCie  LAC0171
#
#       category  total_paid  product_quantity regular_price sale_price
# 272     Memory      282.48                 1        249.99     275.49
# 3085    Memory      309.98                 1        249.99     302.99
# 6920    Memory      276.78                 1        249.99     269.79
# 6970    Memory      290.98                 1        249.99     283.99
# 7215    Memory      325.97                 1        249.99     283.99
# 7218    Memory      295.98                 1        249.99     283.99
# 12453   Memory      242.98                 1        249.99     235.99
# 12476   Memory      235.99                 1        249.99     235.99
# 12493   Memory      235.99                 1        249.99     235.99
# 12682   Memory      235.99                 1        249.99     235.99

# %% [markdown]
# <div class="alert alert-box alert-danger">
#     We will have to examine the amount of data this problem affects after fixing as many of the prices as we can.
#     <br>
#     We can then decide if we wish to adjust the values or delete the orders entirely.
# </div>

# %% [markdown]
# #### Problem 4: Incorrectly placed decimal points

# %%
'''
There are values where the regular_price has been corrupted.
'''
one_decimal_data[one_decimal_data.order_id.isin([496339])]
# Out:
#        order_id  orderline_id                date  \
# 53601    496339       1574664 2018-01-22 20:18:56
#
#                                        name  \
# 53601  Fibaro Single Switch embedded module
#
#                                                     desc   brand      sku  \
# 53601  embedded module to control your consumption ou...  Fibaro  FIB0011
#
#           category  total_paid  product_quantity  regular_price  sale_price  \
# 53601  Accessories       55.98                 1        599.918       56.99
#
#        discount_percentage
# 53601                 90.5

# %% [markdown]
# #### TODO: Check how rounding the values affects the data
# We see in the case above that we will need to round to whole numbers for this solution to have the desired affect.
#
#
# problem 1: sale_price > total_paid - check how many rows, ignore for now?
#
# problem 2: regular_price < sale_price
# - Round all values
# - For the other ones, check if the regular price changed over time and assess whether the correct prices can be deduced from the prices at dates preceeding and following.
# - Calculate the discount percentage after rounding and use negative discounts to identify these?

# %%
''' Let's refresh the data and round the values so that we can detect outliers using the discount_percentage '''

orderline_ids = single_orderline_single_product[
    (single_orderline_single_product.total_paid_decimal_count == 1) &
    (single_orderline_single_product.regular_price_decimal_count == 1) &
    (single_orderline_single_product.sale_price_decimal_count == 1)
].orderline_id

one_decimal_data = single_orderline_single_product[single_orderline_single_product.orderline_id.isin(orderline_ids)].copy()
one_decimal_data[['regular_price', 'sale_price']] = one_decimal_data[['regular_price', 'sale_price']].astype('float')

one_decimal_data.drop(['total_paid_decimal_count', 'regular_price_decimal_count', 'sale_price_decimal_count'], axis=1, inplace=True)

# Tests
sale_greater_than_regular_orderline_ids = pdt.test_regular_greater_or_equal_to_sale(one_decimal_data)
sale_greater_than_total_orderline_ids = pdt.test_total_greater_or_equal_to_sale(one_decimal_data)

# Outliers
outliers = check_for_outliers(one_decimal_data)
print(f"There are {outliers.shape[0]} outliers")
# Out:
# There are corrupted values in regular_price which are less than their corresponding sale_price values.
# This represents 3.30% of the data.
#
# There are corrupted values in total_paid which are less than their corresponding sale_price values.
# This represents 0.68% of the data.
#
# There are 305 outliers

# %%
outliers.sort_values('sale_price_vs_regular_price_percentage_diff', ascending=False).head()
# Out:
#        order_id  orderline_id                date  \
# 53630    496421       1574841 2018-01-22 22:35:46
# 19152    376976       1291907 2017-07-13 18:00:53
# 2474     306824       1139922 2017-01-10 21:16:45
# 23999    392903       1326538 2017-08-28 17:49:16
# 24270    393603       1326648 2017-08-28 19:19:14
#
#                                                     name  \
# 53630             Open - Piece Internal Battery iPhone 6
# 19152  Crucial memory Mac 8GB (2x4GB) SO-DIMM DDR3 16...
# 2474   Crucial memory Mac 8GB (2x4GB) SO-DIMM DDR3 16...
# 23999  Open - Elgato Eve and Energy Plug Power Wirele...
# 24270  Open - Elgato Eve and Energy Plug Power Wirele...
#
#                                                     desc        brand  \
# 53630    Replacement internal battery for Apple iPhone 6  Replacement
# 19152  8GB RAM (2x4GB) SO-DIMM 1600MHZ iMac and Macbo...      Crucial
# 2474   8GB RAM (2x4GB) SO-DIMM 1600MHZ iMac and Macbo...      Crucial
# 23999  Control on and off and sensor power consumptio...       Elgato
# 24270  Control on and off and sensor power consumptio...       Elgato
#
#              sku     category  total_paid  product_quantity  regular_price  \
# 53630  PIE0034-A  Accessories       15.78                 1        349.896
# 19152  CRU0025-2      unknown       85.27                 1        979.785
# 2474   CRU0025-2      unknown       77.98                 1        979.785
# 23999  ELG0033-A   Smartwatch       37.25                 1        499.899
# 24270  ELG0033-A   Smartwatch       37.24                 1        499.899
#
#        sale_price  sale_price_vs_regular_price_percentage_diff
# 53630       11.79                                        96.63
# 19152       65.28                                        93.34
# 2474        72.99                                        92.55
# 23999       37.25                                        92.55
# 24270       37.24                                        92.55

# %%
''' Now round the prices and see if it makes a difference. '''

one_decimal_data[['total_paid', 'regular_price', 'sale_price']] = one_decimal_data[['total_paid', 'regular_price', 'sale_price']].round()

# Tests
sale_greater_than_regular_orderline_ids = pdt.test_regular_greater_or_equal_to_sale(one_decimal_data)
sale_greater_than_total_orderline_ids = pdt.test_total_greater_or_equal_to_sale(one_decimal_data)

# Outliers
outliers = check_for_outliers(one_decimal_data)
print(f"There are {outliers.shape[0]} outliers")
# Out:
# There are corrupted values in regular_price which are less than their corresponding sale_price values.
# This represents 1.18% of the data.
#
# There are corrupted values in total_paid which are less than their corresponding sale_price values.
# This represents 0.47% of the data.
#
# There are 305 outliers

# %%
outliers.sort_values('sale_price_vs_regular_price_percentage_diff', ascending=False).head()
# Out:
#        order_id  orderline_id                date  \
# 53630    496421       1574841 2018-01-22 22:35:46
# 19152    376976       1291907 2017-07-13 18:00:53
# 24293    393659       1326788 2017-08-28 22:31:30
# 23999    392903       1326538 2017-08-28 17:49:16
# 24453    394043       1327664 2017-08-29 21:04:10
#
#                                                     name  \
# 53630             Open - Piece Internal Battery iPhone 6
# 19152  Crucial memory Mac 8GB (2x4GB) SO-DIMM DDR3 16...
# 24293  Open - Elgato Eve and Energy Plug Power Wirele...
# 23999  Open - Elgato Eve and Energy Plug Power Wirele...
# 24453  Open - Elgato Eve and Energy Plug Power Wirele...
#
#                                                     desc        brand  \
# 53630    Replacement internal battery for Apple iPhone 6  Replacement
# 19152  8GB RAM (2x4GB) SO-DIMM 1600MHZ iMac and Macbo...      Crucial
# 24293  Control on and off and sensor power consumptio...       Elgato
# 23999  Control on and off and sensor power consumptio...       Elgato
# 24453  Control on and off and sensor power consumptio...       Elgato
#
#              sku     category  total_paid  product_quantity  regular_price  \
# 53630  PIE0034-A  Accessories        16.0                 1          350.0
# 19152  CRU0025-2      unknown        85.0                 1          980.0
# 24293  ELG0033-A   Smartwatch        37.0                 1          500.0
# 23999  ELG0033-A   Smartwatch        37.0                 1          500.0
# 24453  ELG0033-A   Smartwatch        37.0                 1          500.0
#
#        sale_price  sale_price_vs_regular_price_percentage_diff
# 53630        12.0                                        96.57
# 19152        65.0                                        93.37
# 24293        37.0                                        92.60
# 23999        37.0                                        92.60
# 24453        37.0                                        92.60

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     After visually examining all the values in the above dataframe (shown truncated), it is clear that the decimal point in most of these regular_price values has been placed one point too far to the right.
# </div>

# %%
def _move_decimal_right(row, decimal_col, comparison_col):
    denominator = 10
    while row[decimal_col] >= row[comparison_col]:
        if row[decimal_col] > row[comparison_col]:
            row[decimal_col] /= denominator
        else:
            return row[decimal_col]
    return row[decimal_col] * denominator

def move_regular_price_decimal_point_right_wrt_sale_price(df):
    df.regular_price = [_move_decimal_right(row, 'regular_price', 'sale_price') for index, row in df.iterrows()]
    return df


test_data = outliers.sort_values('sale_price_vs_regular_price_percentage_diff', ascending=False).head(5).copy()
test_data = move_regular_price_decimal_point_right_wrt_sale_price(test_data)
test_data
# Out:
#        order_id  orderline_id                date  \
# 53630    496421       1574841 2018-01-22 22:35:46
# 19152    376976       1291907 2017-07-13 18:00:53
# 24293    393659       1326788 2017-08-28 22:31:30
# 23999    392903       1326538 2017-08-28 17:49:16
# 24453    394043       1327664 2017-08-29 21:04:10
#
#                                                     name  \
# 53630             Open - Piece Internal Battery iPhone 6
# 19152  Crucial memory Mac 8GB (2x4GB) SO-DIMM DDR3 16...
# 24293  Open - Elgato Eve and Energy Plug Power Wirele...
# 23999  Open - Elgato Eve and Energy Plug Power Wirele...
# 24453  Open - Elgato Eve and Energy Plug Power Wirele...
#
#                                                     desc        brand  \
# 53630    Replacement internal battery for Apple iPhone 6  Replacement
# 19152  8GB RAM (2x4GB) SO-DIMM 1600MHZ iMac and Macbo...      Crucial
# 24293  Control on and off and sensor power consumptio...       Elgato
# 23999  Control on and off and sensor power consumptio...       Elgato
# 24453  Control on and off and sensor power consumptio...       Elgato
#
#              sku     category  total_paid  product_quantity  regular_price  \
# 53630  PIE0034-A  Accessories        16.0                 1           35.0
# 19152  CRU0025-2      unknown        85.0                 1           98.0
# 24293  ELG0033-A   Smartwatch        37.0                 1           50.0
# 23999  ELG0033-A   Smartwatch        37.0                 1           50.0
# 24453  ELG0033-A   Smartwatch        37.0                 1           50.0
#
#        sale_price  sale_price_vs_regular_price_percentage_diff
# 53630        12.0                                        96.57
# 19152        65.0                                        93.37
# 24293        37.0                                        92.60
# 23999        37.0                                        92.60
# 24453        37.0                                        92.60

# %%
test_data = outliers[outliers.order_id.isin([512762, 512594, 512579, 512662, 512523, 513175, 301102])].head(5).copy()
test_data = move_regular_price_decimal_point_right_wrt_sale_price(test_data)
test_data
# Out:
#        order_id  orderline_id                date  \
# 723      301102       1131193 2017-01-05 12:48:03
# 57981    512523       1615968 2018-02-16 09:03:37
# 57997    512579       1616105 2018-02-16 09:26:33
# 58006    512594       1616149 2018-02-16 09:36:22
# 58033    512662       1616282 2018-02-16 09:58:57
#
#                                                     name  \
# 723    Crucial memory Mac 8GB (2x4GB) SO-DIMM DDR3 16...
# 57981  Mophie Powerstation 4000mAh Battery Plus Mini ...
# 57997  Mophie Powerstation 6000mAh battery Universal ...
# 58006  Mophie Powerstation 6000mAh battery Universal ...
# 58033  Mophie Powerstation 6000mAh battery Universal ...
#
#                                                     desc    brand        sku  \
# 723    8GB RAM (2x4GB) SO-DIMM 1600MHZ iMac and Macbo...  Crucial  CRU0025-2
# 57981  external battery capacity 4000mAh output volta...   Mophie    MOP0107
# 57997  external battery capacity 6000mAh output volta...   Mophie    MOP0105
# 58006  external battery capacity 6000mAh output volta...   Mophie    MOP0105
# 58033  external battery capacity 6000mAh output volta...   Mophie    MOP0105
#
#           category  total_paid  product_quantity  regular_price  sale_price  \
# 723        unknown       137.0                 1          980.0       137.0
# 57981  Accessories        13.0                 1           70.0         8.0
# 57997  Accessories        14.0                 1           90.0        10.0
# 58006  Accessories        14.0                 1           90.0        10.0
# 58033  Accessories        14.0                 1           90.0        10.0
#
#        sale_price_vs_regular_price_percentage_diff
# 723                                          86.02
# 57981                                        88.57
# 57997                                        88.89
# 58006                                        88.89
# 58033                                        88.89

# %% [markdown]
# <div class="alert alert-box alert-danger">
#     Oops! In lines above we can see that the regular_price has been corrupted and should clearly be slightly lower than the sale_price rather than much greater.
#     <br><br>
#     Let's edit the logic above to keep moving the decimal point until the smallest possible discount_percentage is found.
#     <br><br>
#     Later we can examine the data and decide whether it makes sense to set the regular_price equal to the sale_price or delete the rows.
# </div>

# %%
a = 0.15
a.round(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 2
#       1 a = 0.15
# ----> 2 a.round(2)
#
# AttributeError: 'float' object has no attribute 'round'

# %%
def _calculate_percentage_difference(df, reference_col, comparison_col):
    return ((df[reference_col] - df[comparison_col])/df[reference_col]*100).round(2)

def _move_decimal_right(row, decimal_col, comparison_col):
    denominator = 10

    while True:
        new_row = row.copy()
        new_row[decimal_col] /= denominator
             
        # Check if the new percentage difference is closer to 0
        if abs(_calculate_percentage_difference(new_row, decimal_col, comparison_col)) > abs(_calculate_percentage_difference(row, decimal_col, comparison_col)):
            return row
        else:
            row = new_row
    
def move_regular_price_decimal_point_right_wrt_sale_price(df):
    df = df.apply(lambda row: _move_decimal_right(row, 'regular_price', 'sale_price'), axis=1)
    return df


''' Check the new logic on the one decimal data and rerun the tests '''

one_decimal_data = single_orderline_single_product[single_orderline_single_product.orderline_id.isin(orderline_ids)].copy()
one_decimal_data[['regular_price', 'sale_price']] = one_decimal_data[['regular_price', 'sale_price']].astype('float')
one_decimal_data.drop(['total_paid_decimal_count', 'regular_price_decimal_count', 'sale_price_decimal_count'], axis=1, inplace=True)

# Fix the decimal points
# one_decimal_data = move_regular_price_decimal_point_right_wrt_sale_price(one_decimal_data)

one_decimal_data
# Out:
#        order_id  orderline_id                date  \
# 0        241423       1398738 2017-11-06 12:47:20
# 1        242832       1529178 2017-12-31 17:26:40
# 2        243330       1181923 2017-02-15 17:07:44
# 13       247524       1547886 2018-01-08 21:21:14
# 14       247643       1255453 2017-05-26 11:44:27
# ...         ...           ...                 ...
# 61624    526816       1649042 2018-03-14 09:26:27
# 61625    526843       1649106 2018-03-14 10:39:18
# 61626    526858       1649135 2018-03-14 11:04:14
# 61627    526863       1649141 2018-03-14 11:13:35
# 61654    527017       1649387 2018-03-14 11:35:55
#
#                                                     name  \
# 0      LaCie Porsche Design Desktop Drive 4TB USB 3.0...
# 1                   Parrot 550mAh battery for MiniDrones
# 2                Mac OWC Memory 8GB 1066MHZ DDR3 SO-DIMM
# 13     Crucial memory Mac 16GB (2x8GB) SO-DIMM DDR3 1...
# 14                 Open - Samsung 850 EVO SSD Disk 500GB
# ...                                                  ...
# 61624           Macally Lampcharge Lamp with 4 USB ports
# 61625  Open - LaCie Porsche Design Desktop Lightgrey ...
# 61626         OWC SSD installation kit for iMac 27 "2011
# 61627    Mac memory OWC 8GB (2x4GB) SO-DIMM DDR3 1333MHZ
# 61654          Logitech M220 Wireless Mouse Silent Black
#
#                                                     desc     brand        sku  \
# 0      External Hard Drive 4TB 35-inch USB 3.0 for Ma...     LaCie    LAC0212
# 1      550mAh rechargeable battery for Parrot minidrones    Parrot    PAR0074
# 2      8GB RAM Mac mini iMac MacBook and MacBook Pro ...       OWC    OWC0074
# 13     RAM 16GB (2x8GB) Mac mini (2011) iMac (2010/11...   Crucial  CRU0026-2
# 14     Open hard disk with SSD Mac and PC packaging 2...   Samsung  SAM0068-A
# ...                                                  ...       ...        ...
# 61624  Table lamp with touch control and 4 USB charge...   Macally    MAC0144
# 61625  External Hard Drive Refurbished 35 inches 4TB ...     LaCie  LAC0206-A
# 61626      SSD installation on iMac 27-inch Mid 2011 Kit       OWC    OWC0027
# 61627  RAM 8GB (2x4GB) Mac mini (2011) iMac (2010-201...       OWC  OWC0036-2
# 61654  Bluetooth ambidextrous mouse with nano receive...  Logitech    LOG0224
#
#           category  total_paid  product_quantity  regular_price  sale_price
# 0           Memory      136.15                 1         139.99      129.16
# 1      Accessories       15.76                 1          17.99       10.77
# 2          unknown       84.98                 1          99.99       77.99
# 13         unknown      167.98                 1         163.98      162.99
# 14     Accessories      153.54                 1         179.99      153.54
# ...            ...         ...               ...            ...         ...
# 61624     Hardware       29.98                 1          39.95       24.99
# 61625  Accessories      113.22                 1         139.99      108.23
# 61626  Accessories       47.98                 1          60.99       42.99
# 61627      unknown       96.98                 1          93.98       92.99
# 61654  Accessories       27.98                 1          25.99       22.99
#
# [21971 rows x 12 columns]

# %%
# Round the prices
one_decimal_data[['total_paid', 'regular_price', 'sale_price']] = one_decimal_data[['total_paid', 'regular_price', 'sale_price']].round()

# Calculate the discount percentage
one_decimal_data = add_discount_percentage_col(one_decimal_data)

# Tests
sale_greater_than_regular_orderline_ids = pdt.test_regular_greater_or_equal_to_sale(one_decimal_data)
sale_greater_than_total_orderline_ids = pdt.test_total_greater_or_equal_to_sale(one_decimal_data)

# Outliers
outliers = check_for_outliers(one_decimal_data)
print(f"There are {outliers.shape[0]} outliers")

# %% [markdown]
# <div class="alert alert-block alert-success">
#     
Crucial memory Mac 8GB (2x4GB) SO-DIMM DDR3 16...
# 42008  Elgato Eve and Energy Plug Power Wireless Sens...
# 42168            Budget Request repair Apple MacBook Pro
# 42909   Griffin Survivor iPhone Case Journey 8 Plus /...
# 43503                   Apple iMac repair Budget Request
# 43557                Apple MacBook repair Budget Request
# 43705                Fibaro HomeKit Sensor Door / Window
# 44190               Fibaro Single Switch embedded module
# 44455                Fibaro HomeKit Sensor Door / Window
# 44464  Elgato Eve and Energy Plug Power Wireless Sens...
# 44527               Fibaro Single Switch embedded module
# 44735               Fibaro Single Switch embedded module
# 44775               Fibaro Single Switch embedded module
# 44956               Fibaro Single Switch embedded module
# 45062  Crucial memory Mac 8GB (2x4GB) SO-DIMM DDR3 16...
# 45205               Fibaro Single Switch embedded module
# 46022  Crucial memory Mac 8GB (2x4GB) SO-DIMM DDR3 16...
# 46544               Fibaro Single Switch embedded module
# 46918                     Wi-Fi antenna repair iPhone 4S
# 48191  Elgato Eve and Energy Plug Power Wireless Sens...
# 48722   Griffin Survivor iPhone Case Journey 8 Plus /...
# 49047  Elgato Eve and Energy Plug Power Wireless Sens...
# 49427               Fibaro Single Switch embedded module
# 49589               Fibaro Single Switch embedded module
# 50351               Fibaro Single Switch embedded module
# 50769                       Home button repair iPhone 5s
# 50947  Belkin Cable HDMI 4K Ultra High Speed ​​HDR 2 ...
# 51182  Elgato Eve and Energy Plug Power Wireless Sens...
# 51255   Griffin Survivor iPhone Case Journey 8 Plus /...
# 51484               Fibaro Single Switch embedded module
# 52010   Griffin Survivor iPhone Case Journey 8 Plus /...
# 52326               Fibaro Single Switch embedded module
# 52399            Budget Request repair Apple MacBook Pro
# 52744  Open - Wacom pen Digital Pen CTH-470S / 670s S...
# 52830               Fibaro Single Switch embedded module
# 53026  Open - KX NuGuard NewerTech iPhone Case SE / 5...
# 53056            Budget Request repair Apple MacBook Pro
# 53245               Fibaro Single Switch embedded module
# 53281                iHealth Align glucímetro Smart Mini
# 53315               Fibaro Single Switch embedded module
# 53363               Fibaro Single Switch embedded module
# 53462           Elgato Eve Wireless Sensor Room Interior
# 53502               Fibaro Single Switch embedded module
# 53601               Fibaro Single Switch embedded module
# 53630             Open - Piece Internal Battery iPhone 6
# 53903               Fibaro Single Switch embedded module
# 53975  Crucial memory Mac 8GB (2x4GB) SO-DIMM DDR3 16...
# 54267               Fibaro Single Switch embedded module
# 54367  Crucial memory Mac 8GB (2x4GB) SO-DIMM DDR3 16...
# 54618               Fibaro Single Switch embedded module
# 54915               Fibaro Single Switch embedded module
# 55036               Fibaro Single Switch embedded module
# 55304  Crucial memory Mac 8GB (2x4GB) SO-DIMM DDR3 16...
# 55762  Open - Belkin Audio Adapter (Lightning Charge ...
# 55916               Fibaro Single Switch embedded module
# 55917  Crucial memory Mac 8GB (2x4GB) SO-DIMM DDR3 16...
# 56154            Wacom Intuos Pro Pen Digital Pen + Case
# 56219                Fibaro HomeKit Sensor Door / Window
# 56245  Elgato Eve and Energy Plug Power Wireless Sens...
# 56358                Apple MacBook repair Budget Request
# 56457   Griffin Survivor iPhone Case Journey 8 Plus /...
# 56796      Service installation RAM + HDD + SSD Mac mini
# 57039  Crucial memory Mac 8GB (2x4GB) SO-DIMM DDR3 16...
# 57350   Griffin Survivor iPhone Case Journey 8 Plus /...
# 57895            Budget Request repair Apple MacBook Pro
# 57929  Mophie Powerstation 6000mAh battery Universal ...
# 57931  Mophie Powerstation 6000mAh battery Universal ...
# 57934  Mophie Powerstation 6000mAh battery Universal ...
# 57940  Mophie Powerstation 6000mAh battery Universal ...
# 57941  Mophie Powerstation 4000mAh Battery Plus Mini ...
# 57942  Mophie Powerstation 4000mAh Battery Plus Mini ...
# 57943  Mophie Powerstation 4000mAh Battery Plus Mini ...
# 57944  Mophie Powerstation 4000mAh Battery Plus Mini ...
# 57946  Mophie Powerstation 6000mAh battery Universal ...
# 57955  Mophie Powerstation 6000mAh battery Universal ...
# 57961  Mophie Powerstation 6000mAh battery Universal ...
# 57962  Mophie Powerstation 6000mAh battery Universal ...
# 57963  Mophie Powerstation 6000mAh battery Universal ...
# 57964  Mophie Powerstation Mini Universal 4000mAh Bat...
# 57965  Mophie Powerstation 6000mAh battery Universal ...
# 57966  Mophie Powerstation 4000mAh Battery Plus Mini ...
# 
replacement pointer Wacom Intuos Pen & amp Tou...            Wacom
# 4380                       diagnosis to repair Mac mini.          Service
# 4922   Control on / off and power / consumer remote s...             Pack
# 4958   RAM + HDD installation + SSD in your MacBook /...          Service
# 5476   Control on / off and power / consumer remote s...             Pack
# 5484   Control on / off and power / consumer remote s...             Pack
# 5854   Control on / off and power / consumer remote s...             Pack
# 5974   Control on / off and power / consumer remote s...             Pack
# 6059                        Diagnosis to repair Mac Pro.          Service
# 6089   Control on / off and power / consumer remote s...             Pack
# 6200   Control on / off and power / consumer remote s...             Pack
# 6381   Control on / off and power / consumer remote s...             Pack
# 6382   Control on / off and power / consumer remote s...             Pack
# 6507   Control on / off and power / consumer remote s...             Pack
# 6514   03mm thin cover with screen protector included...             Puro
# 6561                    Amplifier Wi-Fi N 24 GHz Devolo.           Devolo
# 6564   Control on / off and power / consumer remote s...             Pack
# 6727   Control on / off and power / consumer remote s...             Pack
# 6783                    diagnosis to repair MacBook Pro.          Service
# 8246   Replacement pointer Wacom Intuos Pen & amp Tou...            Wacom
# 8628   8GB RAM (2x4GB) SO-DIMM 1600MHZ iMac and Macbo...          Crucial
# 9052   03mm thin cover with screen protector included...             Puro
# 9979                    diagnosis to repair MacBook Air.          Service
# 10123  IPhone Case SE / 5s / 5 ultra resistant for ex...        NewerTech
# 10567  8GB RAM (2x4GB) SO-DIMM 1600MHZ iMac and Macbo...          Crucial
# 10606           SSD 120GB SATA Hard Drive Mac and PC III         Kingston
# 10780  Control on / off and power / consumer remote s...             Pack
# 11019       Set front panel tools and parts for iPad Air           iFixit
# 11132  Pointer with 2048 pressure levels + case for I...            Wacom
# 11868           SSD 120GB SATA Hard Drive Mac and PC III         Kingston
# 12200  64GB pendrive reversible USB-C to USB for Mac ...         Kingston
# 12405                    Pointer parts for Wacom tablets            Wacom
# 12408                   diagnosis to repair MacBook Pro.          Service
# 12655                   diagnosis to repair MacBook Air.          Service
# 13002  8GB RAM (2x4GB) SO-DIMM 1600MHZ iMac and Macbo...          Crucial
# 13031  Replacement pointer Wacom Intuos Pen & amp Tou...            Wacom
# 13052                   diagnosis to repair MacBook Pro.          Service
# 13215  installation RAM HDD + SSD + on your Mac mini ...          Service
# 13223  03mm thin cover with screen protector included...             Puro
# 13811         superfine and portable external DVD burner         Trascend
# 14634          MiniLector glucímoco connected to iPhone.          iHealth
# 14695  03mm thin cover with screen protector included...             Puro
# 14744  Pointer with 2048 pressure levels + case for I...            Wacom
# 14763                   diagnosis to repair MacBook Pro.          Service
# 14947  03mm thin cover with screen protector included...             Puro
# 15296  Repair service including parts and labor for i...           Repair
# 15418                          diagnosis to repair iMac.          Service
# 15432                       Diagnosis to repair Mac Pro.          Service
# 15547  Pointer with 2048 pressure levels + case for I...            Wacom
# 16046                   diagnosis to repair MacBook Pro.          Service
# 17248                   diagnosis to repair MacBook Pro.          Service
# 18978  Repair service including parts and labor for i...           Repair
# 19026       Reconditioned OEM battery for MacBook Pro 13           iFixit
# 19063                          diagnosis to repair iMac.          Service
# 19152  8GB RAM (2x4GB) SO-DIMM 1600MHZ iMac and Macbo...          Crucial
# 19182  32GB flash drive with two different USB-C and ...          SanDisk
# 19548  Repair service including parts and labor for i...           Repair
# 20033              Handset internal speaker for iPhone 6           iFixit
# 20093  Pointer with 2048 pressure levels + case for I...            Wacom
# 20127  Replacement pointer Wacom Intuos Pen & amp Tou...            Wacom
# 20147  rugged case with shock dispersion system for i...          Griffin
# 20321  Cast and impact resistant padded case for iPho...          Griffin
# 21029  IPhone Case SE / 5s / 5 ultra resistant for ex...        NewerTech
# 21232  Cast and impact resistant padded case for iPho...          Griffin
# 21820  8GB RAM (2x4GB) SO-DIMM 1600MHZ iMac and Macbo...          Crucial
# 22164  rugged case with shock dispersion system for i...          Griffin
# 22335        Replacement AC Adapter for Apple iPhone 3G.      Replacement
# 22536  rugged case with shock dispersion system for i...          Griffin
# 22868  Cast and impact resistant padded sleeve for iP...          Griffin
# 22902       Reconditioned OEM battery for MacBook Pro 13           iFixit
# 22945       Reconditioned OEM battery for MacBook Pro 13           iFixit
# 23184  8GB RAM (2x4GB) SO-DIMM 1600MHZ iMac and Macbo...          Crucial
# 23703  Cast and impact resistant padded case for iPho...          Griffin
# 23816  Cast and impact resistant padded case for iPho...          Griffin
# 23999  Control on and off and sensor power consumptio...           Elgato
# 24270  Control on and off and sensor power consumptio...           Elgato
# 24293  Control on and off and sensor power consumptio...           Elgato
# 24453  Control on and off and sensor power consumptio...           Elgato
# 24811  Resistive dispersion system impacts iPhone Cas...          Griffin
# 24840  Case, Green / Transparent iPhone resistant pol...          Griffin
# 24855  Control on / off and power / consumer remote s...             Pack
# 24867  Cast and impact resistant padded case for iPho...          Griffin
# 24890  Resistive dispersion system impacts iPhone Cas...          Griffin
# 25091  Resistive dispersion system impacts iPhone Cas...          Griffin
# 25193  8GB RAM (2x4GB) SO-DIMM 1600MHZ iMac and Macbo...          Crucial
# 25202  rugged case with shock dispersion system for i...          Griffin
# 25341  Cast and impact resistant padded sleeve for iP...          Griffin
# 25617  Resistive dispersion system impacts iPhone Cas...          Griffin
# 25635                          diagnosis to repair iMac.          Service
# 25753  Resistive dispersion system impacts iPhone Cas...          Griffin
# 26755  Cast and impact resistant padded sleeve for iP...          Griffin
# 26894  Case, Green / Transparent iPhone resistant pol...          Griffin
# 26982                          diagnosis to repair iMac.          Service
# 27127       Set front panel tools and parts for iPad Air           iFixit
# 27213  Cast and impact resistant padded sleeve for iP...          Griffin
# 27385  rugged case with shock dispersion system for i...          Griffin
# 28043  64GB pendrive reversible USB-C to USB for Mac ...         Kingston
# 28252  Resistive dispersion system impacts iPhone Cas...          Griffin
# 28274  8GB RAM (2x4GB) SO-DIMM 1600MHZ iMac and Macbo...          Crucial
# 29238  Case, Green / Transparent iPhone resistant pol...          Griffin
# 29409  8GB RAM (2x4GB) SO-DIMM 1600MHZ iMac and Macbo...          Crucial
# 29529  Resistive dispersion system impacts iPhone Cas...          Griffin
# 30250  Pointer with 2048 pressure levels + case for I...            Wacom
# 30451  Repair service including parts and labor for i...           Repair
# 30484  Cast and impact resistant padded case for iPho...          Griffin
# 30625                   Amplifier Wi-Fi N 24 GHz Devolo.           Devolo
# 30719  Control on / off and power / consumer remote s...             Pack
# 30720                      diagnosis to repair Mac mini.          Service
# 31151                   diagnosis to repair MacBook Pro.          Service
# 31489                   diagnosis to repair MacBook Pro.          Service
# 31552  8GB RAM (2x4GB) SO-DIMM 1600MHZ iMac and Macbo...          Crucial
# 31657  Pointer with 2048 pressure levels + case for I...            Wacom
# 31679                          diagnosis to repair iMac.          Service
# 31847  Cast and impact resistant padded case for iPho...          Griffin
# 31910  Cast and impact resistant padded case for iPho...          Griffin
# 32008                   diagnosis to repair MacBook Pro.          Service
# 32199  8GB RAM (2x4GB) SO-DIMM 1600MHZ iMac and Macbo...          Crucial
# 32280                          diagnosis to repair iMac.          Service
# 32529  Repair service including parts and labor for i...           Repair
# 32925  Case, Green / Transparent iPhone resistant pol...          Griffin
# 32949                   Amplifier Wi-Fi N 24 GHz Devolo.           Devolo
# 33012  Cast and impact resistant padded case for iPho...          Griffin
# 33021  Cast and impact resistant padded case for iPho...          Griffin
# 33077  Cast and impact resistant padded case for iPho...          Griffin
# 33438  Case, Green / Transparent iPhone resistant pol...          Griffin
# %% [markdown]
# <div class="alert alert-block alert-danger">
#     Except the values above where the total_paid decimal has been corrupted.
#     <br><br>
#     Let's handle this in the next section where we will be cleaning the total_paid values anyway.
# </div>

# %% [markdown]
# #### Problem 5: total_paid < sale_price & total_paid >> sale_price

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Let's first take a look at the current state of the total_paid data.
# </div>

# %%
completed_sales[completed_sales.total_paid==0]
# Out:
#      order_id  orderline_id                date  \
# 160    296010       1138342 2017-01-09 23:41:57
# 866    301495       1123362 2017-01-03 12:04:16
#
#                                                   name  \
# 160  Tucano Nido Hard-Shell Case MacBook Air 13 "Black
# 866  Svolta Tucano MacBook Pro Sleeve bag / Retina ...
#
#                                                   desc   brand      sku  \
# 160  rigid and slicked rubber feet MacBook Air 13 i...  Tucano  TUC0252
# 866  compact case for MacBook / Air 13 and 13 inche...  Tucano  TUC0277
#
#         category  total_paid  product_quantity regular_price sale_price
# 160  Accessories         0.0                 1          29.9      24.99
# 866  Accessories         0.0                 1          29.9      24.99

# %%
# The 2nd and 3rd rows below have additional orderlines in their orders, the sum of which is equal to the total paid. 
completed_sales[completed_sales.sku=='TUC0252'].head()
# Out:
#        order_id  orderline_id                date  \
# 160      296010       1138342 2017-01-09 23:41:57
# 5596     315031       1159793 2017-01-26 09:56:46
# 9679     327408       1187814 2017-02-22 00:30:18
# 11327    348074       1231937 2017-04-21 08:44:40
# 11538    348607       1233041 2017-04-22 05:41:48
#
#                                                     name  \
# 160    Tucano Nido Hard-Shell Case MacBook Air 13 "Black
# 5596   Tucano Nido Hard-Shell Case MacBook Air 13 "Black
# 9679   Tucano Nido Hard-Shell Case MacBook Air 13 "Black
# 11327  Tucano Nido Hard-Shell Case MacBook Air 13 "Black
# 11538  Tucano Nido Hard-Shell Case MacBook Air 13 "Black
#
#                                                     desc   brand      sku  \
# 160    rigid and slicked rubber feet MacBook Air 13 i...  Tucano  TUC0252
# 5596   rigid and slicked rubber feet MacBook Air 13 i...  Tucano  TUC0252
# 9679   rigid and slicked rubber feet MacBook Air 13 i...  Tucano  TUC0252
# 11327  rigid and slicked rubber feet MacBook Air 13 i...  Tucano  TUC0252
# 11538  rigid and slicked rubber feet MacBook Air 13 i...  Tucano  TUC0252
#
#           category  total_paid  product_quantity regular_price sale_price
# 160    Accessories        0.00                 1          29.9      24.99
# 5596   Accessories     1296.96                 1          29.9      24.99
# 9679   Accessories       53.97                 1          29.9      24.99
# 11327  Accessories       29.98                 1          29.9      24.99
# 11538  Accessories       29.98                 1          29.9      24.99

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     While investigating the total_paid < sale_price values below it was found that two total_paid values were equal to zero.
#     <br><br>
#     Since the regular_price and sale_price values for these two orders are consistent with the others, for which the total_paid = sale_price + €4.99 (shipping fee), for now we will simply set the total_paid equal to €29.98, to get the outliers function to run, and keep these values in mind as we try to solve the problem.
# </div>

# %%
#one_decimal_data[one_decimal_data.total_paid==0].total_paid = 29.98
one_decimal_data.loc[one_decimal_data.order_id==296010, 'total_paid'] = 29.98
one_decimal_data.loc[one_decimal_data.order_id==301495, 'total_paid'] = 29.98
one_decimal_data[one_decimal_data.order_id.isin([296010, 301495])]
# Out:
#      order_id  orderline_id                date  \
# 160    296010       1138342 2017-01-09 23:41:57
# 866    301495       1123362 2017-01-03 12:04:16
#
#                                                   name  \
# 160  Tucano Nido Hard-Shell Case MacBook Air 13 "Black
# 866  Svolta Tucano MacBook Pro Sleeve bag / Retina ...
#
#                                                   desc   brand      sku  \
# 160  rigid and slicked rubber feet MacBook Air 13 i...  Tucano  TUC0252
# 866  compact case for MacBook / Air 13 and 13 inche...  Tucano  TUC0277
#
#         category  total_paid  product_quantity  regular_price  sale_price  \
# 160  Accessories       29.98                 1           29.9       24.99
# 866  Accessories       29.98                 1           29.9       24.99
#
#      sale_price_vs_regular_price_percentage_diff
# 160                                        16.42
# 866                                        16.42

# %%
def check_for_outliers2(df, reference_col='regular_price', comparison_col='sale_price'):
    ''' 
    Check for outliers to see if the decimal value is in the wrong spot. 
    
    We define an outlier as having a percentage difference between the two price 
    values greater than 3 standard deviations from the mean percentage difference.
    '''
    diff_col_name = reference_col + '_' + comparison_col + '_%diff'
    df[diff_col_name] = _calculate_percentage_difference(df, reference_col, comparison_col)
    
    mean_diff = df[diff_col_name].mean()
    std_diff = df[diff_col_name].std()
    threshold = mean_diff + 3 * std_diff
    
    outliers = df[abs(df[diff_col_name]) > threshold]
    
    return outliers


main_col='total_paid'
comparison_col='sale_price'
outliers2 = check_for_outliers2(one_decimal_data, main_col, comparison_col)

print(f"There are {outliers2.shape[0]} outliers")

outliers2.sort_values('total_paid_sale_price_%diff')
# Out:
# There are 212 outliers
#        order_id  orderline_id                date  \
# 2584     307156       1140724 2017-01-11 11:16:20
# 92       274043       1121663 2017-01-02 16:30:49
# 3357     309296       1145769 2017-01-14 11:58:50
# 1197     302589       1130123 2017-01-04 16:51:31
# 949      301709       1123836 2017-01-03 15:09:35
# 3396     309426       1146043 2017-01-14 16:56:51
# 1421     303444       1131913 2017-01-06 01:01:47
# 1556     304005       1133051 2017-01-07 01:04:49
# 1574     304106       1133741 2017-01-07 15:15:34
# 4012     311055       1151189 2017-01-18 12:25:38
# 436      300365       1120796 2017-01-02 10:55:11
# 535      300572       1123325 2017-01-03 11:50:07
# 8056     322063       1175925 2017-02-09 22:21:13
# 620      300790       1121893 2017-01-02 17:54:08
# 1312     303082       1131049 2017-01-05 11:46:34
# 111      281302       1142023 2017-01-12 01:00:05
# 35162    432303       1422680 2017-11-22 21:09:22
# 2306     306362       1138787 2017-01-10 11:08:06
# 3586     310031       1147316 2017-01-15 23:02:54
# 1485     303709       1132437 2017-01-06 18:07:50
# 33021    424710       1403190 2017-11-10 16:02:43
# 23638    391578       1322376 2017-08-22 13:21:49
# 21232    383922       1306373 2017-07-30 11:50:33
# 24867    395651       1335125 2017-09-02 00:46:42
# 26617    403150       1358764 2017-09-22 11:49:18
# 22893    389149       1317374 2017-08-13 13:13:36
# 61258    525011       1644965 2018-03-10 20:49:31
# 20321    380942       1300029 2017-07-23 13:31:34
# 20147    380349       1298776 2017-07-21 12:35:12
# 19446    377935       1293764 2017-07-15 19:00:17
# 6065     316264       1162470 2017-01-28 11:02:05
# 19425    377874       1293648 2017-07-15 14:47:22
# 18973    376451       1290789 2017-07-12 15:20:21
# 16577    369646       1276255 2017-06-27 19:09:59
# 10625    346188       1228092 2017-04-14 18:20:56
# 15479    363490       1263851 2017-06-08 11:37:11
# 11200    347725       1231283 2017-04-20 10:33:58
# 15047    361781       1260564 2017-06-02 18:32:47
# 14464    359696       1256200 2017-05-27 20:03:23
# 12735    352927       1242044 2017-05-05 10:41:45
# 8301     322976       1177848 2017-02-12 17:21:46
# 535                           Kanex Thunderbolt Cable 2m
# 8056            Satechi Slim Bluetooth Keypad Gray Space
# 620                    Startech USB-C 4K HDMI 60Hz White
# 1312   Thule Stróvan MacBook Sleeve Case 15 "(Pro and...
# 111                    Startech USB Adapter VGA-C Blanco
# 35162             Synology DS718 + NAS server Mac and PC
# 2306   Toshiba Canvio Basic Hard Disk 1TB USB 3.0 25 ...
# 3586     21Mochila Thule Crossover MacBook Pro 15 "Black
# 1485   Satechi USB Hub Slim-C to USB-A / HDMI 4K / US...
# 33021  Griffin Survivor Case Tough Journey iPhone 7 /...
# 23638              SwitchEasy iPhone Case 0.35 8/7 White
# 21232  Griffin Survivor Case Tough Journey iPhone 7 /...
# 24867  Griffin Survivor Case for iPhone Journey 7 Cor...
# 26617  SwitchEasy iPhone Case 8 Plus 0.35 / 7 Plus White
# 22893          Moxie Waterproof Case iPhone 6 / 6S Black
# 61258   Wacom Bamboo Stylus Pack 3 first generation tips
# 20321  Griffin Survivor Case Tough Journey iPhone 7 /...
# 20147  Griffin Survivor Case for iPhone Journey 8 Plu...
# 19446  SwitchEasy iPhone Case 8 Plus 0.35 / 7 Plus Black
# 6065                 SwitchEasy iPhone Case 0.35 7 Black
# 19425  iFixit Destornilador Tri-point Y00 A1278 Macbo...
# 18973     Support Kukaclip car + Funda iPhone 6 / 6S Red
# 16577  SwitchEasy iPhone Case 8 Plus 0.35 / 7 Plus Black
# 10625                  OWC Kit of 5 tools for Mac and PC
# 15479  iFixit rubber Kit for MacBook and MacBook Pro ...
# 11200  SwitchEasy iPhone Case 8 Plus 0.35 / 7 Plus Black
# 15047  SwitchEasy iPhone Case 8 Plus 0.35 / 7 Plus Black
# 14464  SwitchEasy iPhone Case 8 Plus 0.35 / 7 Plus Black
# 12735              SwitchEasy iPhone Case 0.35 8/7 White
# 8301   Tempered Glass Screen Protector Moxie Apple Wa...
# 26894  Griffin Survivor iPhone Case Clear 8 Plus / 7 ...
# 33064  Tempered Glass Screen Protector Moxie Apple Wa...
# 28620  SwitchEasy iPhone Case 8 Plus 0.35 / 7 Plus Black
# 55532  Startech Adapter with Micro Mini-Jack 35mm 2 c...
# 54727             Muvit iPhone Case X Case Crystal Clear
# 52594    Moxie Car Support for compatible iPhone Volante
# 50796  Zagg invisibleSHIELD Screen Protector Apple Wa...
# 50651  Zagg invisibleSHIELD Screen Protector Apple Wa...
# 50553  Tempered Glass Screen Protector Moxie Apple Wa...
# 49933  Startech Adapter with Micro Mini-Jack 35mm 2 c...
# 1569                   OWC Kit of 5 tools for Mac and PC
# 49484  D-Link DAP-1320 Wireless N300 Range Extender R...
# 5889                 SwitchEasy iPhone Case 0.35 7 Black
# 14275  Startech Adapter with Micro Mini-Jack 35mm 2 c...
# 47919                Wacom Replacement tips for Intuos 4
# 3259                   OWC Kit of 5 tools for Mac and PC
# 34990  Tempered Glass Screen Protector Moxie Apple Wa...
# 13701  Startech Adapter with Micro Mini-Jack 35mm 2 c...
# 30676  SwitchEasy iPhone Case 8 Plus 0.35 / 7 Plus White
# 5165               SwitchEasy iPhone Case 0.35 8/7 White
# 5302           Moxie Waterproof Case iPhone 6 / 6S White
# 29238  Griffin Survivor iPhone Case Clear 8 Plus / 7 ...
# 8576        Wacom Bamboo Stylus Pack 3 tips Solo and Duo
# 48548                      JBL GO Bluetooth Speaker Blue
# 70     Battery iFixit MacBook Pro 13 "(Mid 2009 to Mi...
# 21100  QNAP NAS server TS-453Bmini | 4GB RAM | 4-bay ...
# 6319   Tempered Glass Screen Protector Moxie Apple Wa...
# 59332      iFixit Tri-Point Screwdriver Y000 Apple Watch
# 50     Griffin Survivor iPhone Case Clear 8 Plus / 7 ...
# 23090  Open - Satechi USB Hub-C to USB-A / Micro SD /...
# 44975       Just Mobile Tenc X Crystal Clear iPhone Case
# 50746       Just Mobile Tenc X Crystal Clear iPhone Case
# 33969   Just Mobile Tenc iPhone Case X Matte Transparent
# 57350   Griffin Survivor iPhone Case Journey 8 Plus /...
# 56457   Griffin Survivor iPhone Case Journey 8 Plus /...
# 30573     LifeProof Case Waterproof iPhone 6s nüüd White
# 7903          Belkin Home Charger Wall Charger USB Black
# 34337   Griffin Survivor iPhone Case Journey 8 Plus /...
# 31847  Griffin Survivor Case Tough Journey iPhone 7 /...
# 42909   Griffin Survivor iPhone Case Journey 8 Plus /...
# 22868  Griffin Survivor Case Journey iPhone 6 Plus an...
# 25753   Griffin Survivor iPhone Case Journey 8 Plus /...
# 27385  Griffin Survivor Case for iPhone Journey 8 Plu...
# 27213  Griffin Survivor Case Journey iPhone 6 Plus an...
# 25091   Griffin Survivor iPhone Case Journey 8 Plus /...
# 25341  Griffin Survivor Case Journey iPhone 6 Plus an...
# 30484  Griffin Survivor Case Tough Journey iPhone 7 /...
# 18476                  OWC Kit of 5 tools for Mac and PC
# 52010   Griffin Survivor iPhone Case Journey 8 Plus /...
# 8270   SanDisk Connect Wireless Flash Drive 16GB Wire...
# 27396  Tucano SOTTILE ultraslim 8/7 Transparent iPhon...
# 32691  Security Torx screwdriver TR6 iFixit Mac Mini ...
# 23288                    Wacom parts 5 points for CTH670
# 26285                    Wacom parts 5 points for CTH670
# 2268   Security Torx screwdriver TR6 iFixit Mac Mini ...
# 33995  Security Torx screwdriver TR6 iFixit Mac Mini ...
# 55579  iFixit rubber Kit for MacBook and MacBook Pro ...
# 56638                    Wacom parts 5 points for CTH670
# 19062  Security Torx screwdriver TR6 iFixit Mac Mini ...
# 57545  Security Torx screwdriver TR6 iFixit Mac Mini ...
# 49379  Security Torx screwdriver TR6 iFixit Mac Mini ...
# 11073  iFixit part adhesive strips Battery iPhone 5s ...
# 29978  Zagg Folio Case Color Keyboard Folio iPad Air ...
# 15274                 NewerTech Complete set of 14 tools
# 46276  Pack of 2 units Zagg Coda Wireless Headsets Black
# 5377   Support Satechi Slim MacBook or iMac Aluminum ...
# 19134  Lexar JumpDrive Lightning USB 3.0 C20i Pendriv...
# 33012  Griffin Survivor Case Tough Journey iPhone 7 /...
# 8318   Startech Adapter with Micro Mini-Jack 35mm 2 c...
# 3902                     iFixit P5 Pentalobe Screwdriver
# 3730   Startech Adapter with Micro Mini-Jack 35mm 2 c...
# 5890                 SwitchEasy iPhone Case 0.35 7 Black
# 30186  SwitchEasy iPhone Case 8 Plus 0.35 / 7 Plus White
# 50455  Tempered Glass Screen Protector Moxie Apple Wa...
# 46712  SwitchEasy iPhone Case 8 Plus 0.35 / 7 Plus White
# 5887                 SwitchEasy iPhone Case 0.35 7 Black
# 33438  Griffin Survivor iPhone Case Clear 8 Plus / 7 ...
# 12312                  OWC Kit of 5 tools for Mac and PC
# 14586                  OWC Kit of 5 tools for Mac and PC
# 15318                  OWC Kit of 5 tools for Mac and PC
# 24840  Griffin Survivor iPhone Case Clear 8 Plus / 7 ...
# 22485                  OWC Kit of 5 tools for Mac and PC
# 10590                  OWC Kit of 5 tools for Mac and PC
# 22409                  OWC Kit of 5 tools for Mac and PC
# 6392                    iFixit Demagnetizer / Magnetizer
# 60397                  OWC Kit of 5 tools for Mac and PC
# 57496  Dodocool Antideslizantes Replacement Cases for...
# 55949                  OWC Kit of 5 tools for Mac and PC
# 41781                  OWC Kit of 5 tools for Mac and PC
# 28337                  OWC Kit of 5 tools for Mac and PC
# 25737                  OWC Kit of 5 tools for Mac and PC
# 55753          Moxie Waterproof Case iPhone 6 / 6S Black
# 32925  Griffin Survivor iPhone Case Clear 8 Plus / 7 ...
# 30162   Wacom Bamboo Stylus Pack 3 first generation tips
# 19552          Moxie Waterproof Case iPhone 6 / 6S Black
# 17480  SwitchEasy iPhone Case 8 Plus 0.35 / 7 Plus Black
# 29689  Tempered Glass Screen Protector Moxie Apple Wa...
# 10461                    Wacom parts 5 points for CTH670
# 36017  MIXIT Belkin Dual USB Power Bank 4000mAh 2.4A ...
# 10575  OtterBox Symmetry Alpha Glass Case + Screen Pr...
# 7023   (Open) Macally Keyboard cover Transparent Keyb...
# 17376                  OWC Kit of 5 tools for Mac and PC
# 20451                  OWC Kit of 5 tools for Mac and PC
# 1065   MyFox Intellitag® intelligent sensors for Home...
# 28252   Griffin Survivor iPhone Case Journey 8 Plus /...
# 24811   Griffin Survivor iPhone Case Journey 8 Plus /...
# 41238                  OWC Kit of 5 tools for Mac and PC
# 53405                  OWC Kit of 5 tools for Mac and PC
# 51926  NewerTech NuGuard Snap-on Case MacBook Pro 13 ...
# 42449         NewerTech MiniDisplay Port to HDMI Adapter
# 13889      Wowewa Protector Tempered Glass iPhone 6 / 6S
# 21769  Satechi Lightning to USB Cable Flexible Black ...
# 50059                  OWC Kit of 5 tools for Mac and PC
# 43426                  OWC Kit of 5 tools for Mac and PC
# 25842                  OWC Kit of 5 tools for Mac and PC
# 46531              SwitchEasy iPhone Case 0.35 8/7 White
# 49500                  OWC Kit of 5 tools for Mac and PC
# 57013                  OWC Kit of 5 tools for Mac and PC
# 52332              SwitchEasy iPhone Case 0.35 8/7 White
# 57168                  OWC Kit of 5 tools for Mac and PC
# 24820                  OWC Kit of 5 tools for Mac and PC
# 30207                  OWC Kit of 5 tools for Mac and PC
# 28760                  OWC Kit of 5 tools for Mac and PC
# 29405                  OWC Kit of 5 tools for Mac and PC
# 1258                           Muvit iPhone Tripod Black
# 28596                  Satechi Aluminum Gray Mouse Space
# 15955    Open - NewerTech NuGuard KX iPad Air Case Black
# 48156  Minibatt iCharger Qi Wireless Charger Quick ch...
# 34564      Griffin DJ Cable 2 iPhone iPad and iPod Touch
# 54461         Griffin Survivor Case for Siri Play Remote
# 199    Svolta Tucano Macbook Pro Sleeve bag / Retina ...
# 48864                      Satechi Aluminum Silver Mouse
# 38781                  OWC Kit of 5 tools for Mac and PC
# 16114   Sen.se GuardPeanut Anti-theft System Intelligent
# 6306                 SwitchEasy iPhone Case 0.35 7 Black
# 1927   Tempered Glass Screen Protector Moxie Apple Wa...
# 8983   Tempered Glass Screen Protector Moxie Apple Wa...
# 53354                  OWC Kit of 5 tools for Mac and PC
# 54256                  OWC Kit of 5 tools for Mac and PC
# 3903   Sonic Dual Conical Satechi Mac v2.0 Speakers B...
# 47346       Otterbox Clearly Protected Gel Case iPhone X
# 29637                  OWC Kit of 5 tools for Mac and PC
# 29659                  OWC Kit of 5 tools for Mac and PC
# 45042                  OWC Kit of 5 tools for Mac and PC
# 31306                  OWC Kit of 5 tools for Mac and PC
# 58805                  OWC Kit of 5 tools for Mac and PC
# 25076                  OWC Kit of 5 tools for Mac and PC
# 322                       Samsung 850 EVO SSD Disk 250GB
# 2527   Tempered Glass Screen Protector Moxie Apple Wa...
# 23580                  OWC Kit of 5 tools for Mac and PC
# 15693       elago Lightning Cable 1m Aluminum Space Gray
# 46898                    iFixit P5 Pentalobe Screwdriver
# 41599  Belkin MIXIT spiral cable jack to jack 18m 35m...
# 39843                  OWC Kit of 5 tools for Mac and PC
# 18407            Moxie 2.5D Tempered glass iPhone 6 / 6S
# 15673      Wowewa Protector Tempered Glass iPhone 6 / 6S
# 28518      Wowewa Protector Tempered Glass iPhone 6 / 6S
# 142    Griffin Survivor Case Tactical Apple Watch 42m...
# 8260     FCM Mac Memory 4GB PC2-5300 DDR2 SO-DIMM 667MHz
# 12181      Wowewa Protector Tempered Glass iPhone 6 / 6S
# 3451   Open - OWC Mount Adapter 25-35 Pro Mac Pro (20...
# 969    Logitech Ultrathin Keyboard Cover Keyboard Cov...
# 9361   Logitech Ultrathin Keyboard Cover Keyboard Cov...
# 1166   Logitech Ultrathin Keyboard Cover Keyboard Cov...
# 14864              Dux STM iPad Case rigid Pro 97 "Black
# 2553   4TB WD My Passport External Hard Drive USB 3.0...
# 23924        Griffin Trainer Armband iPhone 6 / 6S Black
# 52399            Budget Request repair Apple MacBook Pro
# 152         Henge Docks Docking Station MacBook Pro 13 "
# 46342        Satechi USB Hub Adapter Pro-C PD Space Gray
# 16825    Macally Snap-on Case iPhone 6 / 6S metallic red
#
#                                                     desc            brand  \
# 2584   64GB pendrive reversible USB-C to USB for Mac ...         Kingston
# 92     Charging cable and connector magnetic fast lib...          Griffin
# 3357   64GB pendrive reversible USB-C to USB for Mac ...         Kingston
# 1197    Neoprene Sleeve for MacBook Pro Retina 13 inches            Be.ez
# 949    compact case for MacBook / Air 13 and 13 inche...           Tucano
# 3396            Bluetooth locator objects APP for iPhone           TrackR
# 1421    SDHC Memory Card U3 / UHS-I speed of 95MB / 90MB          Samsung
# 1556     Retina MacBook Pro sleeve 15 inch polyurethane.            Be.ez
# 1574   Adapter with reversible USB-C connection HDMI ...         Startech
# 4012   Adapter with USB-C reversible HDMI connection ...         Startech
# 436    Support Macbook with aluminum finish and foldi...          Satechi
# 535                                Thunderbolt Cable 2m.            Kanex
# 8056   Bluetooth keypad and rechargeable battery conn...          Satechi
# 620    C USB-HDMI adapter compatible with Thunderbolt...         Startech
# 1312   Compartmientos cover with pockets for MacBook ...            Thule
# 111    Adapter with reversible USB connection VGA-C (...         Startech
# 35162  Scalable NAS server and transcoding 4K: 4-core...         Synology
# 2306   25-inch External Hard Drive 1TB USB 3.0 for Ma...          Toshiba
# 3586   Lightweight waterproof backpack with several c...            Thule
# 1485   Aluminum adapter with USB Type-C 4K HDMI port ...          Satechi
# 33021  Cast and impact resistant padded case for iPho...          Griffin
# 23638            Ultra Thin Case for iPhone 8/7 in white       SwitchEasy
# 21232  Cast and impact resistant padded case for iPho...          Griffin
# 24867  Cast and impact resistant padded case for iPho...          Griffin
# 26617  Ultra Thin Case for iPhone 8 Plus / 7 Plus in ...       SwitchEasy
# 22893  Case marine case in water and resistant to dir...            Moxie
# 61258  3 Pack Bamboo Stylus pen tips iPad iPhone and ...            Wacom
# 20321  Cast and impact resistant padded case for iPho...          Griffin
# 20147  rugged case with shock dispersion system for i...          Griffin
# 19446  SwitchEasy iPhone Case 8 Plus 0.35 / 7 Plus in...       SwitchEasy
# 6065        Ultra Thin Case for iPhone 7 in black color,       SwitchEasy
# 19425  MacBook Trackpad screwdriver 2008 / MacBook Pr...           iFixit
# 18973  Magnetic car holder with 360 degrees rotating ...         Kukaclip
# 16577  SwitchEasy iPhone Case 8 Plus 0.35 / 7 Plus in...       SwitchEasy
# 10625         Kit of 5 tools for repair / extension Mac.              OWC
# 15479  Kit rubber to the bottom of Macbook / MacBook ...           iFixit
# 11200  SwitchEasy iPhone Case 8 Plus 0.35 / 7 Plus in...       SwitchEasy
# 15047  SwitchEasy iPhone Case 8 Plus 0.35 / 7 Plus in...       SwitchEasy
# 14464  SwitchEasy iPhone Case 8 Plus 0.35 / 7 Plus in...       SwitchEasy
# 12735            Ultra Thin Case for iPhone 8/7 in white       SwitchEasy
# 8301    Screen Protector for Apple Watch tempered glass.            Moxie
# 26894  Case, Green / Transparent iPhone resistant pol...          Griffin
# 33064   Screen Protector for Apple Watch tempered glass.            Moxie
# 28620  SwitchEasy iPhone Case 8 Plus 0.35 / 7 Plus in...       SwitchEasy
# 55532  Adapter headset jack Mini-4-pin mini-jack 2 3 ...         Startech
# 54727              durable and lightweight X iPhone Case            Muvit
# 52594  Support for Car Steering Wheel for iPhone 5 / ...            Moxie
# 50796                  Screen Protector for Apple Watch.         ZaggKeys
# 50651                  Screen Protector for Apple Watch.         ZaggKeys
# 50553   Screen Protector for Apple Watch tempered glass.            Moxie
# 49933  Adapter headset jack Mini-4-pin mini-jack 2 3 ...         Startech
# 1569          Kit of 5 tools for repair / extension Mac.              OWC
# 49484                       DLink repeater signal Wi-Fi.           D-Link
# 5889        Ultra Thin Case for iPhone 7 in black color,       SwitchEasy
# 14275  Adapter headset jack Mini-4-pin mini-jack 2 3 ...         Startech
# 47919  Replacement tips for digital llápices Wacom In...            Wacom
# 3259          Kit of 5 tools for repair / extension Mac.              OWC
# 34990   Screen Protector for Apple Watch tempered glass.            Moxie
# 13701  Adapter headset jack Mini-4-pin mini-jack 2 3 ...         Startech
# 30676  Ultra Thin Case for iPhone 8 Plus / 7 Plus in ...       SwitchEasy
# 5165             Ultra Thin Case for iPhone 8/7 in white       SwitchEasy
# 5302   Case marine case in water and resistant to dir...            Moxie
# 29238  Case, Green / Transparent iPhone resistant pol...          Griffin
# 8576           Replacement tips for Wacom Bamboo Stylus.            Wacom
# 48548  Compact Bluetooth Handsfree for iPhone iPad an...              JBL
# 70     Internal Battery for MacBook Pro 13-inch (Mid ...           iFixit
# 21100  NAS with HDMI 4K (3840x2160) output 4-core pro...             QNAP
# 6319    Screen Protector for Apple Watch tempered glass.            Moxie
# 59332                        Screwdriver for Apple Watch           iFixit
# 50     Case, Green / Transparent iPhone resistant pol...          Griffin
# 23090  Hub with two USB 3.0 ports and SD Micro SD USB...          Satechi
# 44975   Polycarbonate shell with self-heal for iPhone X.      Just Mobile
# 50746   Polycarbonate shell with self-heal for iPhone X.      Just Mobile
# 33969   Polycarbonate shell with self-heal for iPhone X.      Just Mobile
# 57350  Resistive dispersion system impacts iPhone Cas...          Griffin
# 56457  Resistive dispersion system impacts iPhone Cas...          Griffin
# 30573  waterproof case (submersible 2m) 360 degree pr...        Lifeproof
# 7903   Compact wall charger 21A / 10V for iPhone and ...           Belkin
# 34337  Resistive dispersion system impacts iPhone Cas...          Griffin
# 31847  Cast and impact resistant padded case for iPho...          Griffin
# 42909  Resistive dispersion system impacts iPhone Cas...          Griffin
# 22868  Cast and impact resistant padded sleeve for iP...          Griffin
# 25753  Resistive dispersion system impacts iPhone Cas...          Griffin
# 27385  rugged case with shock dispersion system for i...          Griffin
# 27213  Cast and impact resistant padded sleeve for iP...          Griffin
# 25091  Resistive dispersion system impacts iPhone Cas...          Griffin
# 25341  Cast and impact resistant padded sleeve for iP...          Griffin
# 30484  Cast and impact resistant padded case for iPho...          Griffin
# 18476         Kit of 5 tools for repair / extension Mac.              OWC
# 52010  Resistive dispersion system impacts iPhone Cas...          Griffin
# 8270      Wireless 16GB storage for iPhone / iPad / Mac.          SanDisk
# 27396  transparent and flexible cover with 05mm thick...           Tucano
# 32691           Safety screwdriver Mac Mini in late 2014           iFixit
# 23288  Replacement tips for Bamboo Wacom Intuos and C...            Wacom
# 26285  Replacement tips for Bamboo Wacom Intuos and C...            Wacom
# 2268            Safety screwdriver Mac Mini in late 2014           iFixit
# 33995           Safety screwdriver Mac Mini in late 2014           iFixit
# 55579  Kit rubber to the bottom of Macbook / MacBook ...           iFixit
# 56638  Replacement tips for Bamboo Wacom Intuos and C...            Wacom
# 19062           Safety screwdriver Mac Mini in late 2014           iFixit
# 57545           Safety screwdriver Mac Mini in late 2014           iFixit
# 49379           Safety screwdriver Mac Mini in late 2014           iFixit
# 11073  adhesive strips replacement battery for iPhone...           iFixit
# 29978  Case with Bluetooth Keyboard for iPad Air 2 Sp...         ZaggKeys
# 15274           portable kit of 14 tools for Mac and PC.        NewerTech
# 46276  Pack 2 Bluetooth wireless headset with autonom...             Pack
# 5377   Stand with aluminum finish and practical desig...          Satechi
# 19134  Lightning to USB external memory for iPad and ...            Lexar
# 33012  Cast and impact resistant padded case for iPho...          Griffin
# 8318   Adapter headset jack Mini-4-pin mini-jack 2 3 ...         Startech
# 3902   Pentalobe screwdriver P5 for MacBook Air and M...           iFixit
# 3730   Adapter headset jack Mini-4-pin mini-jack 2 3 ...         Startech
# 5890        Ultra Thin Case for iPhone 7 in black color,       SwitchEasy
# 30186  Ultra Thin Case for iPhone 8 Plus / 7 Plus in ...       SwitchEasy
# 50455   Screen Protector for Apple Watch tempered glass.            Moxie
# 46712  Ultra Thin Case for iPhone 8 Plus / 7 Plus in ...       SwitchEasy
# 5887        Ultra Thin Case for iPhone 7 in black color,       SwitchEasy
# 33438  Case, Green / Transparent iPhone resistant pol...          Griffin
# 12312         Kit of 5 tools for repair / extension Mac.              OWC
# 14586         Kit of 5 tools for repair / extension Mac.              OWC
# 15318         Kit of 5 tools for repair / extension Mac.              OWC
# 24840  Case, Green / Transparent iPhone resistant pol...          Griffin
# 22485         Kit of 5 tools for repair / extension Mac.              OWC
# 10590         Kit of 5 tools for repair / extension Mac.              OWC
# 22409         Kit of 5 tools for repair / extension Mac.              OWC
# 6392           degausser tool and screwdriver Magnetizer           iFixit
# 60397         Kit of 5 tools for repair / extension Mac.              OWC
# 57496  slip silicone case that enhance comfort and st...         Dodocool
# 55949         Kit of 5 tools for repair / extension Mac.              OWC
# 41781         Kit of 5 tools for repair / extension Mac.              OWC
# 28337         Kit of 5 tools for repair / extension Mac.              OWC
# 25737         Kit of 5 tools for repair / extension Mac.              OWC
# 55753  Case marine case in water and resistant to dir...            Moxie
# 32925  Case, Green / Transparent iPhone resistant pol...          Griffin
# 30162  3 Pack Bamboo Stylus pen tips iPad iPhone and ...            Wacom
# 19552  Case marine case in water and resistant to dir...            Moxie
# 17480  SwitchEasy iPhone Case 8 Plus 0.35 / 7 Plus in...       SwitchEasy
# 29689   Screen Protector for Apple Watch tempered glass.            Moxie
# 10461  Replacement tips for Bamboo Wacom Intuos and C...            Wacom
# 36017      External Battery Dual USB for iPhone and iPad           Belkin
# 10575  Pack OtterBox Symmetry Case + Screen Protector...         Otterbox
# 7023             Keyboard Cover for Apple Magic Keyboard          Macally
# 17376         Kit of 5 tools for repair / extension Mac.              OWC
# 20451         Kit of 5 tools for repair / extension Mac.              OWC
# 1065   Kit of 5 antitheft security system sensors My ...            MyFox
# 28252  Resistive dispersion system impacts iPhone Cas...          Griffin
# 24811  Resistive dispersion system impacts iPhone Cas...          Griffin
# 41238         Kit of 5 tools for repair / extension Mac.              OWC
# 53405         Kit of 5 tools for repair / extension Mac.              OWC
# 51926  Protector for MacBook Pro 13 elegant and easy ...        NewerTech
# 42449                 Adapter mini Display Port to HDMI.        NewerTech
# 13889         Tempered glass protector for iPhone 6 / 6S           Wowewa
# 21769  Lightning durable and flexible 15 cm cable len...          Satechi
# 50059         Kit of 5 tools for repair / extension Mac.              OWC
# 43426         Kit of 5 tools for repair / extension Mac.              OWC
# 25842         Kit of 5 tools for repair / extension Mac.              OWC
# 46531            Ultra Thin Case for iPhone 8/7 in white       SwitchEasy
# 49500         Kit of 5 tools for repair / extension Mac.              OWC
# 57013         Kit of 5 tools for repair / extension Mac.              OWC
# 52332            Ultra Thin Case for iPhone 8/7 in white       SwitchEasy
# 57168         Kit of 5 tools for repair / extension Mac.              OWC
# 24820         Kit of 5 tools for repair / extension Mac.              OWC
# 30207         Kit of 5 tools for repair / extension Mac.              OWC
# 28760         Kit of 5 tools for repair / extension Mac.              OWC
# 29405         Kit of 5 tools for repair / extension Mac.              OWC
# 1258   tripod system with articulated segments for iP...            Muvit
# 28596  Aluminum mat with ultra soft non-slip surface ...          Satechi
# 15955  IPad case ultra resistant to extreme condition...        NewerTech
# 48156  Practical charger compatible wireless devices ...         Minibatt
# 34564  Cable iPhone and iPod Touch iPad DJ applicatio...          Griffin
# 54461                     Siri Remote control protector.          Griffin
# 199    briefcase with external pocket and zipper MacB...           Tucano
# 48864  Aluminum mat with ultra soft non-slip surface ...          Satechi
# 38781         Kit of 5 tools for repair / extension Mac.              OWC
# 16114  Anti-theft sensor with intelligent compact des...           Sen.se
# 6306        Ultra Thin Case for iPhone 7 in black color,       SwitchEasy
# 1927    Screen Protector for Apple Watch tempered glass.            Moxie
# 8983    Screen Protector for Apple Watch tempered glass.            Moxie
# 53354         Kit of 5 tools for repair / extension Mac.              OWC
# 54256         Kit of 5 tools for repair / extension Mac.              OWC
# 3903   Speakers matte finish sleek design and volume ...          Satechi
# 47346  a transparent cover piece and flexible TPU for...         Otterbox
# 29637         Kit of 5 tools for repair / extension Mac.              OWC
# 29659         Kit of 5 tools for repair / extension Mac.              OWC
# 45042         Kit of 5 tools for repair / extension Mac.              OWC
# 31306         Kit of 5 tools for repair / extension Mac.              OWC
# 58805         Kit of 5 tools for repair / extension Mac.              OWC
# 25076         Kit of 5 tools for repair / extension Mac.              OWC
# 322    SSD hard drive Mac and PC 25 inch 250GB SATA I...          Samsung
# 2527    Screen Protector for Apple Watch tempered glass.            Moxie
# 23580         Kit of 5 tools for repair / extension Mac.              OWC
# 15693  Charging cable connection and synchronization ...            Elago
# 46898  Pentalobe screwdriver P5 for MacBook Air and M...           iFixit
# 41599              Coiled Cable for iPhone iPad and iPod           Belkin
# 39843         Kit of 5 tools for repair / extension Mac.              OWC
# 18407     Screen Saver tempered glass for iPhone 6 / 6S.            Moxie
# 15673         Tempered glass protector for iPhone 6 / 6S           Wowewa
# 28518         Tempered glass protector for iPhone 6 / 6S           Wowewa
# 142    Anti-shock Case with Screen Protector for Appl...          Griffin
# 8260   4GB RAM Mac mini and iMac (2006/07) and MacBoo...              FCM
# 12181         Tempered glass protector for iPhone 6 / 6S           Wowewa
# 3451   SSD or hard drive for Mac Pro 2.5 refitted ada...              OWC
# 969    Ultrathin cover and cover with Bluetooth keybo...         Logitech
# 9361   Ultrathin cover and cover with Bluetooth keybo...         Logitech
# 1166   Ultrathin cover and cover with Bluetooth keybo...         Logitech
# 14864  Resistant sheath with support for the new case...              STM
# 2553   4TB External Hard Drive USB 3.0 with Mac and P...  Western Digital
# 23924          Bracelet iPhone 6 / 6S sports waterproof.          Griffin
# 52399                   diagnosis to repair MacBook Pro.          Service
# 152    Dock and support with multiple connections for...      Henge Docks
# 46342  Hub with USB port PD-C-C USB HDMI 4K SD MicroS...          Satechi
# 16825  Case rigid and resistant metallic tones iPhone...          Macally
#
#              sku              category  total_paid  product_quantity  \
# 2584     KIN0123           Accessories        2.98                 1
# 92       GRT0425           Accessories        3.98                 1
# 3357     KIN0123           Accessories        3.99                 1
# 1197     BEZ0178           Accessories        4.98                 1
# 949      TUC0277           Accessories        6.98                 1
# 3396     TRK0007               unknown        8.98                 1
# 1421     SAM0105                Memory        8.98                 1
# 1556     BEZ0159           Accessories        8.98                 1
# 1574     STA0038           Accessories        9.98                 1
# 4012     STA0037           Accessories        9.98                 1
# 436      SAT0013           Accessories        9.98                 1
# 535      KAN0025           Accessories       21.99                 1
# 8056     SAT0043           Accessories       18.98                 1
# 620      STA0052           Accessories       19.98                 1
# 1312     THU0044           Accessories       19.98                 1
# 111      STA0036           Accessories       16.98                 1
# 35162    SYN0180              Hardware      261.86                 1
# 2306     TOS0018                Memory       33.98                 1
# 3586     THU0025           Accessories       44.99                 1
# 1485     SAT0008           Accessories       39.98                 1
# 33021    GRT0466           Accessories        8.03                 1
# 23638    SHE0044           Accessories        7.98                 1
# 2584  Travelstar Kingston Pen Drive 3C Duo micro USB...
# 3357  Travelstar Kingston Pen Drive 3C Duo micro USB...
#
#                                                    desc     brand      sku  \
# 92    Charging cable and connector magnetic fast lib...   Griffin  GRT0425
# 2584  64GB pendrive reversible USB-C to USB for Mac ...  Kingston  KIN0123
# 3357  64GB pendrive reversible USB-C to USB for Mac ...  Kingston  KIN0123
#
#          category  total_paid  product_quantity  regular_price  sale_price  \
# 92    Accessories        3.98                 1         34.990       24.99
# 2584  Accessories        2.98                 1        302.803       23.99
# 3357  Accessories        3.99                 1        302.803       23.99
#
#       sale_price_vs_regular_price_percentage_diff  total_paid_sale_price_%diff
# 92                                          28.58                      -527.89
# 2584                                        92.08                      -705.03
# 3357                                        92.08                      -501.25

# %% [markdown]
# <div class="alert alert-box alert-danger">
#     There are rows (above) which must be fixed by moving the decimal right.
# </div>

# %%
completed_sales[completed_sales.sku=='MAC0121']
# Out:
#        order_id  orderline_id                date  \
# 6011     316116       1162133 2017-01-27 21:59:12
# 16825    370351       1278732 2017-06-30 14:15:57
# 42609    457539       1483664 2017-12-08 21:41:21
# 48594    477933       1528572 2017-12-31 10:41:38
#
#                                                   name  \
# 6011   Macally Snap-on Case iPhone 6 / 6S metallic red
# 16825  Macally Snap-on Case iPhone 6 / 6S metallic red
# 42609  Macally Snap-on Case iPhone 6 / 6S metallic red
# 48594  Macally Snap-on Case iPhone 6 / 6S metallic red
#
#                                                     desc    brand      sku  \
# 6011   Case rigid and resistant metallic tones iPhone...  Macally  MAC0121
# 16825  Case rigid and resistant metallic tones iPhone...  Macally  MAC0121
# 42609  Case rigid and resistant metallic tones iPhone...  Macally  MAC0121
# 48594  Case rigid and resistant metallic tones iPhone...  Macally  MAC0121
#
#           category  total_paid  product_quantity regular_price sale_price
# 6011   Accessories       33.41                 1          9.95       4.95
# 16825  Accessories      847.98                 1          9.95       7.99
# 42609  Accessories       38.96                 1          9.95       4.99
# 48594  Accessories       18.92                 1          9.95       4.74

# %% [markdown]
# <div class="alert alert-box alert-danger">
#     There are rows (above) which must be fixed by moving the decimal left.
# </div>

# %%
completed_sales[completed_sales.order_id.isin([301709, 309426, 303444, 311055, 300572])]
# Out:
#       order_id  orderline_id                date  \
# 535     300572       1123325 2017-01-03 11:50:07
# 949     301709       1123836 2017-01-03 15:09:35
# 1421    303444       1131913 2017-01-06 01:01:47
# 3396    309426       1146043 2017-01-14 16:56:51
# 4012    311055       1151189 2017-01-18 12:25:38
#
#                                                    name  \
# 535                          Kanex Thunderbolt Cable 2m
# 949   Svolta Tucano MacBook Pro Sleeve bag / Retina ...
# 1421              Samsung Pro + SDHC UHS Class 3 | 32GB
# 3396                         Bravo Locator Black Trackr
# 4012                  Startech USB-C HDMI Adapter Black
#
#                                                    desc     brand      sku  \
# 535                               Thunderbolt Cable 2m.     Kanex  KAN0025
# 949   compact case for MacBook / Air 13 and 13 inche...    Tucano  TUC0277
# 1421   SDHC Memory Card U3 / UHS-I speed of 95MB / 90MB   Samsung  SAM0105
# 3396           Bluetooth locator objects APP for iPhone    TrackR  TRK0007
# 4012  Adapter with USB-C reversible HDMI connection ...  Startech  STA0037
#
#          category  total_paid  product_quantity regular_price sale_price
# 535   Accessories       21.99                 1         47.99      46.99
# 949   Accessories        6.98                 1          29.9      24.99
# 1421       Memory        8.98                 1         52.01      28.99
# 3396      unknown        8.98                 1         29.99      29.99
# 4012  Accessories        9.98                 1         39.99      29.99

# %%
''' There are no other single-orderline orders to compare this order to so we cannot fix it.'''
single_orderline_single_product[single_orderline_single_product.sku=='KAN0025']
# Out:
#      order_id  orderline_id                date                        name  \
# 535    300572       1123325 2017-01-03 11:50:07  Kanex Thunderbolt Cable 2m
#
#                       desc  brand      sku     category  total_paid  \
# 535  Thunderbolt Cable 2m.  Kanex  KAN0025  Accessories       21.99
#
#      product_quantity regular_price sale_price  regular_price_decimal_count  \
# 535                 1         47.99      46.99                            1
#
#      sale_price_decimal_count  total_paid_decimal_count
# 535                         1                         1

# %%
''' There are no other single-orderline orders with the same sale_price so we cannot fix it. '''
single_orderline_single_product[single_orderline_single_product.sku=='SAM0105']
# Out:
#       order_id  orderline_id                date  \
# 780     301253       1122867 2017-01-03 01:34:02
# 1421    303444       1131913 2017-01-06 01:01:47
#
#                                        name  \
# 780   Samsung Pro + SDHC UHS Class 3 | 32GB
# 1421  Samsung Pro + SDHC UHS Class 3 | 32GB
#
#                                                   desc    brand      sku  \
# 780   SDHC Memory Card U3 / UHS-I speed of 95MB / 90MB  Samsung  SAM0105
# 1421  SDHC Memory Card U3 / UHS-I speed of 95MB / 90MB  Samsung  SAM0105
#
#      category  total_paid  product_quantity regular_price sale_price  \
# 780    Memory       35.98                 1         52.01      31.99
# 1421   Memory        8.98                 1         52.01      28.99
#
#       regular_price_decimal_count  sale_price_decimal_count  \
# 780                             1                         1
# 1421                            1                         1
#
#       total_paid_decimal_count
# 780                          1
# 1421                         1

# %%
single_orderline_single_product[single_orderline_single_product.sku=='TRK0007']
# Out:
#        order_id  orderline_id                date                        name  \
# 652      300873       1122059 2017-01-02 19:06:03  Bravo Locator Black Trackr
# 1339     303174       1131257 2017-01-05 13:31:53  Bravo Locator Black Trackr
# 2245     306172       1138338 2017-01-09 23:40:17  Bravo Locator Black Trackr
# 2393     306585       1139370 2017-01-10 16:30:41  Bravo Locator Black Trackr
# 3396     309426       1146043 2017-01-14 16:56:51  Bravo Locator Black Trackr
# 3432     309540       1146288 2017-01-14 21:53:54  Bravo Locator Black Trackr
# 3436     309546       1146305 2017-01-14 22:02:01  Bravo Locator Black Trackr
# 8490     323517       1178966 2017-02-13 12:52:16  Bravo Locator Black Trackr
# 8845     324522       1181473 2017-02-15 12:23:41  Bravo Locator Black Trackr
# 9275     325912       1184656 2017-02-18 11:03:48  Bravo Locator Black Trackr
# 9373     326294       1185405 2017-02-19 17:43:33  Bravo Locator Black Trackr
# 11637    348903       1233631 2017-04-23 13:56:18  Bravo Locator Black Trackr
# 12919    353548       1243217 2017-05-07 21:16:33  Bravo Locator Black Trackr
# 13169    354417       1244985 2017-05-10 09:53:16  Bravo Locator Black Trackr
# 13360    355052       1246314 2017-05-11 20:14:18  Bravo Locator Black Trackr
# 1339                          1
# 2245                          1
# 2393                          1
# 3396                          1
# 3432                          1
# 3436                          1
# 8490                          1
# 8845                          1
# 9275                          1
# 9373                          1
# 11637                         1
# 12919                         1
# 13169                         1
# 13360                         1
# 13441                         1
# 13802                         1
# 14656                         1
# 14880                         1
# 14987                         1
# 15048                         1
# 15154                         1
# 15172                         1
# 15454                         1
# 15552                         1
# 15864                         1
# 15902                         1
# 16129                         1
# 16709                         1
# 18820                         1
# 22411                         1
# 23553                         1
# 24814                         1
# 25589                         1
# 25717                         1
# 25844                         1
# 26502                         1
# 26976                         1
# 27999                         1
# 28475                         1
# 29706                         1
# 30667                         1
# 31000                         1
# 32950                         1
# 39116                         1
# 40709                         1
# 41769                         1
# 43169                         1
# 43176                         1
# 43788                         1
# 44692                         1
# 46028                         1
# 46500                         1
# 47478                         1
# 47604                         1
# 47667                         1
# 47860                         1
# 49602                         1
# 50004                         1
# 50074                         1
# 50785                         1
# 52254                         1
# 52779                         1
# 53563                         1
# 54216                         1
# 56295                         1
# 58394                         1

# %% [markdown]
# <div class="alert alert-box alert-danger">
#     There are rows (above) which simply have the wrong total_paid value and cannot be fixed by moving the decimal.
#     <br><br>
#     Perhaps orderlines from these orders are missing in the data dump?
#     <br><br>
#     To fix these we will have to:
#     <br>
#     - Identify them as outliers
#     <br>
#     - Delete rows which do not have other orders with the same sale_price. The cannot be fixed.
#     <br>
#     - Get the mode (most common value) total_paid of other single-orderline orders of the same product, which are not outliers and have the same sale_price.
#     <br>
#     - Assign this value as the total_paid for the corrupted row
# </div>

# %%
# def _calculate_percentage_difference(df, reference_col, comparison_col):
#     return ((df[reference_col] - df[comparison_col])/df[reference_col]*100).round(2)

# def _move_decimal_right(row, decimal_col, comparison_col):
#     denominator = 10

#     while True:
#         new_row = row.copy()
#         new_row[decimal_col] /= denominator
             
#         # Check if the new percentage difference is closer to 0
#         if abs(_calculate_percentage_difference(new_row, decimal_col, comparison_col)) > abs(_calculate_percentage_difference(row, decimal_col, comparison_col)):
#             return row
#         else:
#             row = new_row
    
# def move_regular_price_decimal_point_right_wrt_sale_price(df):
#     df = df.apply(lambda row: _move_decimal_right(row, 'regular_price', 'sale_price'), axis=1)
#     return df


# ''' Check the new logic on the one decimal data and rerun the tests '''

# one_decimal_data = single_orderline_single_product[single_orderline_single_product.orderline_id.isin(orderline_ids)].copy()
# one_decimal_data[['regular_price', 'sale_price']] = one_decimal_data[['regular_price', 'sale_price']].astype('float')
# one_decimal_data.drop(['total_paid_decimal_count', 'regular_price_decimal_count', 'sale_price_decimal_count'], axis=1, inplace=True)

# # Fix the decimal points
# one_decimal_data = move_regular_price_decimal_point_right_wrt_sale_price2(one_decimal_data)

# # Round the prices
# one_decimal_data[['total_paid', 'regular_price', 'sale_price']] = one_decimal_data[['total_paid', 'regular_price', 'sale_price']].round()

# # Calculate the discount percentage
# one_decimal_data = add_discount_percentage_col(one_decimal_data)

# # Tests
# sale_greater_than_regular_orderline_ids = pdt.test_regular_greater_or_equal_to_sale(one_decimal_data)
# sale_greater_than_total_orderline_ids = pdt.test_total_greater_or_equal_to_sale(one_decimal_data)

# # Outliers
# outliers = check_for_outliers(one_decimal_data)
# print(f"There are {outliers.shape[0]} outliers")

# %%
one_decimal_data[one_decimal_data.order_id.isin([304373, 311465, 281302, 303444, 310031, 274043, 307156, 309296])]

# %%
one_decimal_data[one_decimal_data.orderline_id.isin(sale_greater_than_total_orderline_ids)].sort_values('discount_percentage', ascending=False).head()

# %%
sale_price_greater_than_regular[(sale_price_greater_than_regular.regular_price < sale_price_greater_than_regular.sale_price) & (sale_price_greater_than_regular.total_paid < sale_price_greater_than_regular.sale_price)]

# %% [markdown]
# <div class="alert alert-box alert-info">
#     Let's split the data at the decimal point and examine whether we can determine any patterns by the number of digits after the decimal point.
# </div>

# %% [markdown]
# ## Decimal count = 1 = 0 = 1
#
# <div class="alert alert-box alert-info">
#     total_paid_decimal_count==1  & regular_price_decimal_count==0 & sale_price_decimal_count==1
# </div>

# %%
1. Turn them into floats

# %%
order_ids = prices[
((prices.regular_price_decimal_count == 0 )| (prices.regular_price_decimal_count == 1)) &
((prices.promo_price_decimal_count == 0) | (prices.promo_price_decimal_count == 1)) &
((prices.sale_price_decimal_count == 0) | (prices.sale_price_decimal_count == 1)) 
].orderline_id

zero_one_decimal_data = completed_sales[completed_sales.orderline_id.isin(order_ids)].copy()
zero_one_decimal_data

# %% [markdown]
# ## Decimal count == 0
#
# <div class="alert alert-box alert-info">
#     regular_price_decimal_count == promo_price_decimal_count == sale_price_decimal_count == 0
# </div>
# <div class="alert alert-box alert-warning">
#     There are no sale_price values with zero decimal points.
#     <br>
#     The regular_price and promo_price values with no decimal points appear to have been accidentally saved as ints instead of floats.
#     <br>
#     Let's select only these values and see if this logic is correct
# </div>

# %%
order_ids = prices[
((prices.regular_price_decimal_count == 0)) &
((prices.promo_price_decimal_count == 0)) &
((prices.sale_price_decimal_count == 0) | (prices.sale_price_decimal_count == 1)) 
].orderline_id

zero_decimal_count = completed_sales[completed_sales.orderline_id.isin(order_ids)].copy()
zero_decimal_count

# %%
# Transform the three columns to floats
zero_decimal_count[['regular_price', 'promo_price', 'sale_price']] = zero_decimal_count[['regular_price', 'promo_price', 'sale_price']].astype('float')

# Run the tests
incorrect_reg_pro_ids = pdt.test_regular_greater_or_equal_to_promo(zero_decimal_count)

# %%
display(zero_decimal_count[zero_decimal_count.regular_price >= zero_decimal_count.promo_price].head())

# %% [markdown]
# <div class="alert alert-box alert-success">
#     After viewing the entire df (shown above in truncated form) we can conclude that our assumption is basically correct.
# </div>
#
# <div class="alert alert-box alert-danger">
#     However, some of the sale_price values still do not match the regular_price or the promo_price.
#     <br>
#     <br>
#     Furthermore, even though the total_price values only ever had one decimal point, for some of them it is clearly in the wrong place.
# </div>
# <div class="alert alert-box alert-info">
#     To clean the sale_price values we must first clean the total_price values as it is sometimes equal to neither regular_price nor promo_price but is close to total_paid.
#     <br>
#     <br>
#     To this end we must select a subset where all the orderlines in the order are within the zero_decimal_count df.
#     <br>
#     If the order we are examining has other otherlines which are in completed_sales but not in zero_decimal_count then we cannot be sure we have all the data to confirm the total_paid value is correct.
#     <br>
#     <br>
#     We must check the distribution of total_price values wrt to sale_price, then promo_price and regular_price to determine whether the difference can be explained by shipping costs or whether the decimal point is in the wrong place.
#     <br>
#     <br>
#     We can then analyse the distribution of sale_price values wrt to regular_price and wrt promo_price and examine the outliers.
# </div>

# %%
''' Filter out orders which do not have all their orderlines in zero_decimal_count'''

# Get the count of orderlines per order from completed_sales
completed_sales_orderline_counts = completed_sales.groupby('order_id')['orderline_id'].count().reset_index()
completed_sales_orderline_counts.rename(columns={'orderline_id': 'completed_count'}, inplace=True)

# Do the same for zero_decimal_count
zero_dec_orderline_counts = zero_decimal_count.groupby('order_id')['orderline_id'].count().reset_index()
zero_dec_orderline_counts.rename(columns={'orderline_id': 'zero_count'}, inplace=True)

# Merge to find orders with matching counts
valid_orders = pd.merge(completed_sales_orderline_counts, zero_dec_orderline_counts, on='order_id')
valid_orders = valid_orders[valid_orders['completed_count'] == valid_orders['zero_count']]

# Filter zero_decimal_count for these valid order_ids
zero_decimal_count__complete_orders = zero_decimal_count[zero_decimal_count['order_id'].isin(valid_orders['order_id'])].copy()

print("zero_decimal_count.shape:", zero_decimal_count.shape)
print("zero_decimal_count_subset.shape:", zero_decimal_count__complete_orders.shape)

# %%
valid_orders[valid_orders]

# %%
''' Multiply regular_price, promo_price and sale_price by the product_quantity to compare them to the total_paid. '''

zero_decimal_count__complete_orders['regular_price_total'] = zero_decimal_count__complete_orders.regular_price*zero_decimal_count__complete_orders.product_quantity
zero_decimal_count__complete_orders['promo_price_total'] = zero_decimal_count__complete_orders.promo_price*zero_decimal_count__complete_orders.product_quantity
zero_decimal_count__complete_orders['sale_price_total'] = zero_decimal_count__complete_orders.sale_price*zero_decimal_count__complete_orders.product_quantity

''' First check the orders with only one orderline for simplicity '''
zero_decimal_count__complete_orders__single_orderline

# %%
incorrect_pro_sale_ids = pdt.test_promo_greater_or_equal_to_sale(zero_decimal_count)

# %% [markdown]
# ## Evaluate corrupted data with multiple decimal points

# %% [markdown]
# ### regular_price_decimal_count==1	promo_price_decimal_count==0	sale_price_decimal_count==2

# %%
order_ids = prices[
(prices.regular_price_decimal_count == 1) &
(prices.promo_price_decimal_count == 0) &
(prices.sale_price_decimal_count == 2) 
].orderline_id

data = completed_sales[completed_sales.orderline_id.isin(order_ids)].copy()
data

# %% [markdown]
# ### regular_price_decimal_count==1	promo_price_decimal_count==1	sale_price_decimal_count==2

# %%
order_ids = prices[
(prices.regular_price_decimal_count == 1) &
(prices.promo_price_decimal_count == 1) &
(prices.sale_price_decimal_count == 2) 
].orderline_id

data = completed_sales[completed_sales.orderline_id.isin(order_ids)].copy()
data

# %% [markdown]
# ### sale_price_decimal_count == 2

# %%
order_ids = prices[
(prices.sale_price_decimal_count == 2) 
].orderline_id

data = completed_sales[completed_sales.orderline_id.isin(order_ids)].copy()
data

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     FOR SALE_PRICE_DEC_COUNT: YOU NEED TO SPLIT THE SALE PRICE COLUMN AND FIGURE OUT IF THERE ARE ALWAYS 2 DIGITS AFTER THE DEC AND 2 BETWEEN THE TWO. THEN YOU MIGHT BE ABLE TO FIX THEM ALL IN ONE GO.
#
# </div>

# %% [markdown]
# ### regular_price_decimal_count == 0

# %%
# Let's take a look at the values with zero decimal points. It is possible that these have been incorrectly stored as ints.
reg_price_zero_dec_ids = prices[(prices.regular_price_decimal_count == 0)].orderline_id

zero_dec_test_data = completed_sales[completed_sales.orderline_id.isin(reg_price_zero_dec_ids)].copy()
zero_dec_test_data

# %%
pro_price_zero_dec_ids = prices[(prices.promo_price_decimal_count == 0)].orderline_id

zero_dec_test_data = completed_sales[completed_sales.orderline_id.isin(pro_price_zero_dec_ids)].copy()
zero_dec_test_data

# %%
reg_pro_price_zero_dec_ids = prices[(prices.regular_price_decimal_count == 0) & (prices.promo_price_decimal_count == 0)].orderline_id

zero_dec_test_data = completed_sales[completed_sales.orderline_id.isin(zero_dec_ids)].copy()
zero_dec_test_data

# %% [markdown]
# <div class="alert alert-block alert-success">
#     The
# </div>

# %% [markdown]
# ### Check sale_price

# %%
temp = prices.copy()
temp[temp.sale_price_decimal_count!=1]

# %%
temp = (
    temp.assign(
        sale_price_split = lambda x: x['sale_price'].str.split(r'\.'),
        decimal_places = lambda x: len(x['sale_price_split'][1]))
)
temp.head(5)

# %%
temp[temp.decimal_places != 2]

# %% [markdown]
# ### Transform orderlines.unit_price to floats

# %%
def transform_unit_price_to_floats(df):
    """
    Transform the orderlines.unit_price price column to floats.
    Some of the values have two decimal points. 
    For these values we will remove the leftmost decimal and transform all values to floats.
    The correct position of the decimal point will be determined by merging orderlines, 
    products, orders and brands, and comparing the price values.
    
    Args:
        df (pd.DataFrame): The orderlines data
    
    Returns:
        pd.DataFrame: The orderlines data with the unit_price column transformed from str to float values.
    """
    return (
        df.assign(unit_price = df.unit_price.str.split('.')
                  .apply(lambda x : x[0]+x[1]+'.'+x[2] if len(x)==3 else x[0]+'.'+ x[1])
                  .astype(float)
        )
    )

# %%
completed_sales['regular_price'].str.count(r'\.')

# %%
def split_str_on_dots_and_append_decimal(df, col):
    '''Remove the decimal points from the strings and append .00'''
    return df.assign(promo_price=df[col]
                     .str.split('.')
                     .str.join('')
                     .apply(lambda x: x+'.00')
                    )

def _insert_decimal_at_string_position(s, pos):
    '''Insert a decimal point at a given position in a string'''
    s = s.split('.')
    s = s[0] + s[1]
    s = s[:pos]+'.'+s[pos:]
    return s 
    
def _insert_decimal_in_regular_price(row):
    '''
    Keep moving the decimal point towards the end of the regular_price 
    string until the sale_price is lower or equal to the price.
    Then transform the regular_price string to a float and round it to two decimal places.
    '''
    decimal_position = 1
    row.regular_price = _insert_decimal_at_string_position(row.regular_price, decimal_position)
    
    while float(row.regular_price) < row.sale_price:
        if round(float(row.regular_price), 0) == round(row.sale_price, 0):
            row.sale_price = round(float(row.price), 2)
            return round(float(row.regular_price), 2)
        else:
            row.regular_price = _insert_decimal_at_string_position(row.regular_price, decimal_position)
            decimal_position += 1

    return round(float(row.price), 2)

def transform_regular_price_to_float(df):
    df.regular_price = [_insert_decimal_in_regular_price(row) for index, row in df.iterrows()]
    return df

# %% [markdown]
# # Solution attempt 1
# Move the decimal points until reg >= promo >= sale and run the tests to see if it works

# %%
def start_pipeline(df):
    '''Make a copy of the pipeline to prevent corrupting the original data'''
    return df.copy()

def split_str_on_dots_and_append_decimal(df, col):
    '''Remove the decimal points from the strings and append .00'''
    return df.assign(promo_price=df[col]
                     .str.split('.')
                     .str.join('')
                     .apply(lambda x: x+'.00')
                    )

def _insert_decimal_at_string_position(s, pos):
    '''Insert a decimal point at a given position in a string'''
    s = s.split('.')
    s = s[0] + s[1]
    s = s[:pos]+'.'+s[pos:]
    return s 
    
def _insert_decimal_in_regular_price(row):
    '''
    Keep moving the decimal point towards the end of the regular_price 
    string until the sale_price is lower or equal to the price.
    Then transform the regular_price string to a float and round it to two decimal places.
    '''
    decimal_position = 1
    row.regular_price = _insert_decimal_at_string_position(row.regular_price, decimal_position)
    
    while float(row.regular_price) < row.sale_price:
        if round(float(row.regular_price), 0) == round(row.sale_price, 0):
            row.sale_price = round(float(row.price), 2)
            return round(float(row.regular_price), 2)
        else:
            row.regular_price = _insert_decimal_at_string_position(row.regular_price, decimal_position)
            decimal_position += 1

    return round(float(row.price), 2)

def transform_regular_price_to_float(df):
    df.regular_price = [_insert_decimal_in_regular_price(row) for index, row in df.iterrows()]
    return df

def _insert_decimal_in_promo_price(row, decimal_position = -2):
    '''
    If the euro value of the regular_price is equal to the euro value of the promo_price, 
    set the promo_price equal to regular_price and return it.
    This is because some promo_prices are slightly larger than their equivalent prices, e.g. 12.95 - 12.99
    
    Otherwise, keep moving the decimal point towards the start of the string until the promo_price is lower than the price.
    Then transform the string to a float and round it to two decimal places.
    '''
    
    while float(row.promo_price) > row.regular_price:
        if round(float(row.promo_price), 0) == round(row.regular_price, 0):
            row.promo_price = row.regular_price
            return row.promo_price
        else:
            row.promo_price = _insert_decimal_at_string_position(row.promo_price, decimal_position)
            decimal_position += -1
    
    return round(float(row.promo_price), 2)

def transform_promo_price_to_floats(df):
    df.promo_price = [_insert_decimal_in_promo_price(row) for index, row in df.iterrows()]
    return df
    
def calculate_products_discounts(df):
    return df.assign(
        discount=round(df.price - df.promo_price, 2),
        discount_pc = round((df.price - df.promo_price)/df.price * 100, 2)
    )

def calculate_sales_discounts(df):
    return (df
            .assign(
                sales_discount=round(df.price - df.sale_price, 2),
                sales_discount_pc = round((df.price - df.sale_price)/df.price * 100, 2)
            )
           )

temp = completed_sales.copy()

temp = (temp
        .pipe(start_pipeline)
        .pipe(split_str_on_dots_and_append_decimal, 'regular_price')
        #.pipe(split_and_join_regular_prices)
        .pipe(transform_regular_price_to_float)
        .pipe(split_str_on_dots_and_append_decimal, 'promo_price')
        #.pipe(split_and_join_promo_prices)
        .pipe(transform_promo_price_to_floats)
        .pipe(calculate_products_discounts)
        .pipe(calculate_sales_discounts)
)

temp
