# %% [markdown]
# # products.csv
#
# * **sku** – stock keeping unit: a unique identifier for each product
# * **name** – product name
# * **desc** – product description
# * **price** – base price of the product, in euros
# * **promo_price** – promotional price, in euros
# * **in_stock** – whether or not the product was in stock at the moment of the data extraction
# * **type** – a numerical code for product type

# %% [markdown]
# ## Import the data

# %%
import pandas as pd
import numpy as np
import re

pd.options.display.max_rows = 500

products_original = pd.read_csv('../../data/products.csv')
products_original.head()
# Out:
#        sku                                           name  \
# 0  RAI0007              Silver Rain Design mStand Support
# 1  APP0023              Apple Mac Keyboard Keypad Spanish
# 2  APP0025               Mighty Mouse Apple Mouse for Mac
# 3  APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4  KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
#
#                                                 desc  price promo_price  \
# 0       Aluminum support compatible with all MacBook  59.99     499.899
# 1          USB ultrathin keyboard Apple Mac Spanish.     59     589.996
# 2                             mouse Apple USB cable.     59     569.898
# 3              IPhone dock and USB Cable Apple iPod.     25     229.997
# 4  2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
#
#    in_stock      type
# 0         1      8696
# 1         0  13855401
# 2         0      1387
# 3         0      1230
# 4         1      1364

# %% [markdown]
# ## Data exploration

# %%
products = products_original.copy()
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19326 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          19326 non-null  object
#  1   name         19326 non-null  object
#  2   desc         19319 non-null  object
#  3   price        19280 non-null  object
#  4   promo_price  19326 non-null  object
#  5   in_stock     19326 non-null  int64
#  6   type         19276 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.0+ MB

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>price</b> and <b>promo_price</b> must be transformed to float and type and <b>in_stock</b> can be removed.
# </div>

# %%
products.drop(['type', 'in_stock'], axis=1, inplace=True)

# %%
products.nunique()
# Out:
# sku            10579
# name           10373
# desc            7098
# price           2690
# promo_price     4614
# dtype: int64

# %%
products[products.sku.duplicated()]
# Out:
#            sku                                               name  \
# 101    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 102    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 103    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 104    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 105    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# ...        ...                                                ...
# 16831  APP2302  Apple MacBook Pro 13 "Core i5 Touch Bar 33GHz ...
# 16833  APP2303  Apple MacBook Pro 13 "Core i5 Touch Bar 33GHz ...
# 18190  PAR0077                         Parrot Bebop Drone 2 Power
# 18308  NKI0010              Nokia Wireless sphygmomanometer Plata
# 18514  PLA0035          Bluetooth Headset Plantronics Explorer 80
#
#                                                     desc        price  \
# 101          MacBook Pro laptop 133 inches (MD101Y / A).         1199
# 102          MacBook Pro laptop 133 inches (MD101Y / A).         1199
# 103          MacBook Pro laptop 133 inches (MD101Y / A).         1199
# 104          MacBook Pro laptop 133 inches (MD101Y / A).         1199
# 105          MacBook Pro laptop 133 inches (MD101Y / A).         1199
# ...                                                  ...          ...
# 16831  New MacBook Pro 13-inch Core i5 Touch Bar 33 G...   26.155.941
# 16833  New MacBook Pro 13 inch Touch Bar 33 GHz Core ...  237.559.421
# 18190  Drone cuadricóptero quality camera integrated ...        699.9
# 18308     Sphygmomanometer for iPhone iPad and iPod App.       129.99
# 18514  egonómico wireless headset design for iPhone i...        39.99
#
#       promo_price
# 101    11.455.917
# 102    11.455.917
# 103    11.455.917
# 104    11.455.917
# 105    11.455.917
# ...           ...
# 16831  26.155.941
# 16833  23.755.942
# 18190   6.733.892
# 18308   1.149.899
# 18514     349.896
#
# [8747 rows x 5 columns]

# %%
products[products.sku=='APP0390']
# Out:
#          sku                                               name  \
# 100  APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 101  APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 102  APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 103  APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 104  APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 105  APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 106  APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 107  APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 108  APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
#
#                                             desc price promo_price
# 100  MacBook Pro laptop 133 inches (MD101Y / A).  1199  11.455.917
# 101  MacBook Pro laptop 133 inches (MD101Y / A).  1199  11.455.917
# 102  MacBook Pro laptop 133 inches (MD101Y / A).  1199  11.455.917
# 103  MacBook Pro laptop 133 inches (MD101Y / A).  1199  11.455.917
# 104  MacBook Pro laptop 133 inches (MD101Y / A).  1199  11.455.917
# 105  MacBook Pro laptop 133 inches (MD101Y / A).  1199  11.455.917
# 106  MacBook Pro laptop 133 inches (MD101Y / A).  1199  11.455.917
# 107  MacBook Pro laptop 133 inches (MD101Y / A).  1199  11.455.917
# 108  MacBook Pro laptop 133 inches (MD101Y / A).  1199  11.455.917

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     We will need to drop these duplicated values.
# </div>

# %% [markdown]
# #### Missing values

# %%
products.isna().sum()
# Out:
# sku             0
# name            0
# desc            7
# price          46
# promo_price     0
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     We need to remove and rows with missing <b>price</b> values.
# </div>

# %%
before = products.shape[0]
products = products[~products.price.isna()]
after = products.shape[0]
print(f"{before-after} rows removed.")
# Out:
# 46 rows removed.

# %% [markdown]
# #### Missing descriptions

# %%
names_of_products_without_descriptions = products[products.desc.isna()].name.tolist()
names_of_products_without_descriptions
# Out:
# ['Open - Purple 2TB WD 35 "PC Security Mac hard drive and NAS',
#  'Open - Apple Smart Keyboard Pro Keyboard Folio iPad 9.7 "',
#  'Synology DS718 + NAS Server | 10GB RAM',
#  'Open - Kanex USB-C Gigabit Ethernet Adapter MacBook 12 "',
#  'Hyper Pearl 1600mAh battery Mini USB Mirror and Comic Blond',
#  'OtterBox External Battery Power Pack 20000 mAHr',
#  'Open - Honeywell thermostat Lyric zonificador T6 Intelligent Wireless (cable)']

# %%
products[products.desc.isna()]
# Out:
#              sku                                               name desc  \
# 16126  WDT0211-A  Open - Purple 2TB WD 35 "PC Security Mac hard ...  NaN
# 16128  APP1622-A  Open - Apple Smart Keyboard Pro Keyboard Folio...  NaN
# 17843    PAC2334             Synology DS718 + NAS Server | 10GB RAM  NaN
# 18152  KAN0034-A  Open - Kanex USB-C Gigabit Ethernet Adapter Ma...  NaN
# 18490    HTE0025  Hyper Pearl 1600mAh battery Mini USB Mirror an...  NaN
# 18612    OTT0200    OtterBox External Battery Power Pack 20000 mAHr  NaN
# 18690  HOW0001-A  Open - Honeywell thermostat Lyric zonificador ...  NaN
#
#            price promo_price
# 16126        107     814.659
# 16128  1.568.206   1.568.206
# 17843     566.35   5.659.896
# 18152      29.99     237.925
# 18490      24.99       22.99
# 18612      79.99       56.99
# 18690     199.99   1.441.174

# %% [markdown]
# <div class="alert alert-block alert-info">
#     There are only 7 missing descriptions. We can simply look up the products online and add them.
# </div>

# %% [markdown]
# #### Explore price values

# %%
# Create a copy of the dataset
price_temp = products.copy()

# create a new column with the amount of dots in the unit_price column
price_temp['num_decimals'] = price_temp['price'].str.count(r'\.')

# show the rows with more than one dot
price_temp.query('num_decimals > 1').shape[0]
# Out:
# 431

# %%
# show the rows with more than two dots
price_temp.query('num_decimals > 2').shape[0]
# Out:
# 0

# %%
price_temp.query('num_decimals > 1').head(5)
# Out:
#            sku                                               name  \
# 665  CRU0015-2  Crucial memory Mac 16GB (2x8GB) SO-DIMM DDR3 1...
# 792    APP0672                    Apple iPhone 5S 16GB Space Gray
# 797    APP0673                        Apple iPhone 5S 16GB Silver
# 827    PAC0339             NewerTech miniStack 4TB Hard Drive Mac
# 885    PAC0376       OWC Mercury Elite Pro Dual Thunderbolt + 8TB
#
#                                                   desc      price promo_price  \
# 665  RAM 16GB (2x8GB) 135V MacBook Pro iMac (2012/2...  1.639.792   1.629.894
# 792             New iPhone 5S 16G Libre (ME432Y / AB).  4.694.994   4.694.994
# 797              New Free iPhone 5S 16GB (ME433Y / A).  4.090.042   4.090.042
# 827                 External Box Hard Drive Mac + 4TB.  2.199.791   2.199.901
# 885  RAID outer box 35 inch SATA connection Thunder...  5.609.698   5.549.895
#
#      num_decimals
# 665             2
# 792             2
# 797             2
# 827             2
# 885             2

# %%
# show the rows with more than two dots
price_temp.query('num_decimals < 1').shape[0]
# Out:
# 11528

# %%
price_temp.query('num_decimals < 1').head(5)
# Out:
#          sku                                               name  \
# 1    APP0023                  Apple Mac Keyboard Keypad Spanish
# 2    APP0025                   Mighty Mouse Apple Mouse for Mac
# 3    APP0072      Apple Dock to USB Cable iPhone and iPod white
# 5    APP0073     Apple Composite AV Cable iPhone and iPod white
# 8  KIN0001-2  Mac memory Kingston 4GB (2x2GB) 667MHz DDR2 SO...
#
#                                                 desc price promo_price  \
# 1          USB ultrathin keyboard Apple Mac Spanish.    59     589.996
# 2                             mouse Apple USB cable.    59     569.898
# 3              IPhone dock and USB Cable Apple iPod.    25     229.997
# 5  IPhone and iPod AV Cable Dock to Composite Video.    45     420.003
# 8  RAM 4GB (2x2GB) Mac mini and iMac (2006/07) Ma...    74     669.904
#
#    num_decimals
# 1             0
# 2             0
# 3             0
# 5             0
# 8             0

# %% [markdown]
# #### Explore promo price values

# %%
# Create a copy of the dataset
promo_price_temp = products.copy()

# create a new column with the amount of dots in the unit_price column
promo_price_temp['num_decimals'] = promo_price_temp['promo_price'].str.count(r'\.')

# show the rows with more than one dot
promo_price_temp.query('num_decimals > 1').shape[0]
# Out:
# 12902

# %%
# show the rows with more than two dots
price_temp.query('num_decimals > 2').shape[0]
# Out:
# 0

# %% [markdown]
# #### Compare both
#
# <div class="alert alert-block alert-info">
#     There are far more corrupted values in <b>promo_price</b> so let's check the values where only <b>promo_price</b> is corrupted and compare the values
# </div>

# %%
# Create a copy of the dataset
products_temp = products.copy()

# create a new column with the amount of dots in the unit_price column
products_temp['num_decimals_price'] = products_temp['price'].str.count(r'\.')
products_temp['num_decimals_promo_price'] = products_temp['promo_price'].str.count(r'\.')

# show the rows with more than one dot
products_temp.query('num_decimals_price != num_decimals_promo_price')
# Out:
#              sku                                               name  \
# 1        APP0023                  Apple Mac Keyboard Keypad Spanish
# 2        APP0025                   Mighty Mouse Apple Mouse for Mac
# 3        APP0072      Apple Dock to USB Cable iPhone and iPod white
# 5        APP0073     Apple Composite AV Cable iPhone and iPod white
# 8      KIN0001-2  Mac memory Kingston 4GB (2x2GB) 667MHz DDR2 SO...
# ...          ...                                                ...
# 19316    REP0407                                iPad battery repair
# 19317    REP0403                             iPad LCD screen repair
# 19318    REP0402                           iPad touch screen repair
# 19319    KNO0032     Knomo MacBook Pro Beauchamp Backpack 14 "Black
# 19320    REP0076           repair Full screen iPad (1st generation)
#
#                                                     desc      price  \
# 1              USB ultrathin keyboard Apple Mac Spanish.         59
# 2                                 mouse Apple USB cable.         59
# 3                  IPhone dock and USB Cable Apple iPod.         25
# 5      IPhone and iPod AV Cable Dock to Composite Video.         45
# 8      RAM 4GB (2x2GB) Mac mini and iMac (2006/07) Ma...         74
# ...                                                  ...        ...
# 19316  Repair service including parts and labor for iPad  6.999.003
# 19317  Repair service including parts and labor for iPad     159.99
# 19318  Repair service including parts and labor for iPad     139.99
# 19319  Backpack thin nylon mesh internal compartment ...        179
# 19320  Repair service including parts and labor for iPad     149.99
#
#       promo_price  num_decimals_price  num_decimals_promo_price
# 1         589.996                   0                         1
# 2         569.898                   0                         1
# 3         229.997                   0                         1
# 5         420.003                   0                         1
# 8         669.904                   0                         1
# ...           ...                 ...                       ...
# 19316       69.99                   2                         1
# 19317   1.599.898                   1                         2
# 19318   1.399.897                   1                         2
# 19319   1.699.905                   0                         2
# 19320   1.499.795                   1                         2
#
# [14078 rows x 7 columns]

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     In rows 1-5 above we see that even with a single decimal place, the <b>promo_price</b> has been corrupted.<br>
#     In row 19316 we see that the <b>price</b> has been corrupted and the <b>promo_price</b> is correct.
# </div>

# %% [markdown]
# ## Clean products

# %%
products = products_original.copy()

products_before = products.shape[0]

print("Products.shape - Initial:", products.shape[0])
# Drop the type and in_stock columns 
products.drop('type', axis=1, inplace=True, errors='ignore')
products.drop('in_stock', axis=1, inplace=True, errors='ignore')

print("Products.shape - After dropping deprecated columns:", products.shape[0])

#  Drop duplicate rows based on sku value
products.drop_duplicates(subset='sku', inplace=True)

print("Products.shape - After dropping duplicate sku values:", products.shape[0])

# Check for products without descriptions
names_of_products_without_descriptions = products[products.desc.isna()].name.tolist()
# Add missing descriptions
missing_descriptions = [
    '2TB Mac hard drive and Nas',
    'Apple keyboard for iPad 9.7',
    'NAS server with 10GB RAM',
    'Ethernet adapter for Macbook 12',
    'Luxury power bank combined with powder, 2 mirrors - normal and 3x magnification, Illuminated under mirror with LED, Low weight and compact dimensions',
    'Battery capacity: 20,000 mAh; ultra-stable: outer shell made of durable synthetic rubber (military standard, withstands drops from up to 2 metres) ; protection: dust and splash proof: military standard iP54; battery level indicator and super fast charging; USB port can be connected to charger and other devices',
    'Smart thermostat designed to provide automatic time and temperature control of heating systems in homes and apartments. '
]
for i in range(len(names_of_products_without_descriptions)):
    products.loc[products.name == names_of_products_without_descriptions[i], 'desc'] = missing_descriptions[i]

def start_pipeline(df):
    '''Make a copy of the pipeline to prevent corrupting the original data'''
    return df.copy()

def remove_missing_prices(df, col):
    return df[~df[col].isna()]


products = (products
        .pipe(start_pipeline)
        .pipe(remove_missing_prices,col='price')
)


print("Products.shape - After removing rows with missing price values:", products.shape[0])

products_after = products.shape[0]

print('\n')
print(f"{products_before-products_after} missing and duplicated values were removed from products")
print(f"This represents {(products_before-products_after)/products_before * 100:.2f}% of the data.")
print("\n\n")

products
# Out:
# Products.shape - Initial: 19326
# Products.shape - After dropping deprecated columns: 19326
# Products.shape - After dropping duplicate sku values: 10579
# Products.shape - After removing rows with missing price values: 10534
#
#
# 8792 missing and duplicated values were removed from products
# This represents 45.49% of the data.
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price promo_price
# 0           Aluminum support compatible with all MacBook  59.99     499.899
# 1              USB ultrathin keyboard Apple Mac Spanish.     59     589.996
# 2                                 mouse Apple USB cable.     59     569.898
# 3                  IPhone dock and USB Cable Apple iPod.     25     229.997
# 4      2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
# ...                                                  ...    ...         ...
# 19321  compact and portable stand vertically or horiz...  29.99     269.903
# 19322  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19323  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19324  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19325  Backpack with capacity of 14 liter compartment...  69.95     649.903
#
# [10534 rows x 5 columns]

# %% [markdown]
# # Debug prices

# %%
def test_col_vals_are_greater_or_equal_to_other(df, greater_col, lesser_col):
    num_incorrect_vals = df[df[greater_col] < df[lesser_col]].shape[0]
    if num_incorrect_vals == 0:
        print(f"All of the {greater_col} values are greater or equal to the corresponding {lesser_col} values.\n")
        return pd.DataFrame()
    else:
        print(f"There are corrupted values in {greater_col} which are less than their corresponding {lesser_col} values.")
        print(f"This respresents {num_incorrect_vals/df.shape[0]*100:.2f}% of the data.\n")
        corrupted_price_skus = df[df[greater_col] < df[lesser_col]].sku
        return corrupted_price_skus

def test_price_greater_or_equal_to_promo_price(df):
    incorrect_val_ids = test_col_vals_are_greater_or_equal_to_other(df, 'price', 'promo_price')
    return incorrect_val_ids

def add_discount_percentage_col(df):
    df['discount_percentage'] = (df.price - df.promo_price)/df.price*100
    return df

def check_for_outliers(df):
    ''' 
    Check for outliers to see if the decimal value was in the wrong spot. 
    
    We define an outlier as having a discount percentage in price and promo_price 
    greater than 3 standard deviations from the mean discount percentage
    '''

    mean_diff = df['discount_percentage'].mean()
    std_diff = df['discount_percentage'].std()
    threshold = mean_diff + 3 * std_diff
    
    outliers = df[df['discount_percentage'] > threshold]
    
    return outliers

# %%
# Create a copy of the dataset
products_temp = products.copy()

# create a new column with the amount of dots in the unit_price column
products_temp['price_decimal_count'] = products_temp['price'].str.count(r'\.')
products_temp['promo_price_decimal_count'] = products_temp['promo_price'].str.count(r'\.')

# Group by the num decimal columns and get the count & percentage for each group
grouped_counts = products_temp.groupby(
    ['price_decimal_count', 'promo_price_decimal_count']
).size().reset_index(name='count')

# Calculate the percentage of each group relative to the total number of rows
total_rows = len(products_temp)
grouped_counts['percentage'] = (grouped_counts['count'] / total_rows) * 100

# Display the resulting dataframe
grouped_counts.sort_values('percentage', ascending=False)
# Out:
#    price_decimal_count  promo_price_decimal_count  count  percentage
# 4                    1                          1   4610   43.763053
# 5                    1                          2   2312   21.947978
# 2                    0                          2   2009   19.071578
# 1                    0                          1   1104   10.480349
# 8                    2                          2    276    2.620087
# 0                    0                          0    102    0.968293
# 7                    2                          1     98    0.930321
# 3                    1                          0     20    0.189861
# 6                    2                          0      3    0.028479

# %% [markdown]
# ## price_decimal_count = promo_price_decimal_count = 0

# %%
skus = products_temp[
    (products_temp.price_decimal_count == 0) &
    (products_temp.promo_price_decimal_count == 0)
].sku

zero_zero_decimal_data = products_temp[products_temp.sku.isin(skus)].copy()
zero_zero_decimal_data[['price', 'promo_price']] = zero_zero_decimal_data[['price', 'promo_price']].astype('float')

# %%
test_price_greater_or_equal_to_promo_price(zero_zero_decimal_data)

zero_zero_decimal_data = add_discount_percentage_col(zero_zero_decimal_data)

outliers = check_for_outliers(zero_zero_decimal_data)
outliers
# Out:
# All of the price values are greater or equal to the corresponding promo_price values.
#            sku                                               name  \
# 15936  PAC2059  Second hand - Apple iMac 20 "Core 2 Duo 266GHz...
# 15954  PAC2065  Second hand - Apple iMac 24 "Core 2 Duo 28 GHz...
# 17706  PAC2199  Second hand - Apple iMac 20 "Core 2 Duo 226GHz...
#
#                                                     desc   price  promo_price  \
# 15936  Refurbished iMac 20 inch Core 2 Duo 266GHz | 4...  1199.0        409.0
# 15954  Computer Refurbished iMac 24 inch Core 2 Duo 2...  1799.0        499.0
# 17706  Refurbished iMac 20 inch Core 2 Duo | 2GB RAM ...  1199.0        259.0
#
#        price_decimal_count  promo_price_decimal_count  discount_percentage
# 15936                    0                          0            65.888240
# 15954                    0                          0            72.262368
# 17706                    0                          0            78.398666

# %% [markdown]
# <div class="alert alert-block alert-success">
#     The test passes and the outliers do not have the decimal point in the wrong place.
#     <br><br>
#     The data is clean.
#     <br><br>
#     For now we will assume that values with no decimal point are whole numbers which were saved as ints.
# </div>

# %% [markdown]
# ## price_decimal_count = 1,  promo_price_decimal_count = 0

# %%
skus = products_temp[
    (products_temp.price_decimal_count == 1) &
    (products_temp.promo_price_decimal_count == 0)
].sku

one_zero_decimal_data = products_temp[products_temp.sku.isin(skus)].copy()
one_zero_decimal_data[['price', 'promo_price']] = one_zero_decimal_data[['price', 'promo_price']].astype('float')

corrupted_price_skus = test_price_greater_or_equal_to_promo_price(one_zero_decimal_data)
one_zero_decimal_data[one_zero_decimal_data.sku.isin(corrupted_price_skus)]
# Out:
# There are corrupted values in price which are less than their corresponding promo_price values.
# This respresents 15.00% of the data.
#            sku                                          name  \
# 10966  SAN0092          SanDisk Ultra USB 3.0 128GB pendrive
# 11038  SAN0110  SanDisk Ultra Flair Flash Drive 16GB USB 3.0
# 13487  SAN0158  SanDisk Cruzer Dial Flash Drive 16GB USB 2.0
#
#                                                     desc  price  promo_price  \
# 10966  Pendrive USB 3.0 Flash Drive 128G for Mac and PC.  44.99         47.0
# 11038  USB 3.0 flash drive 16GB USB Flash Drive Mac a...   8.99          9.0
# 13487  Ultra compact flash drive with built-dial for ...   7.99          9.0
#
#        price_decimal_count  promo_price_decimal_count
# 10966                    1                          0
# 11038                    1                          0
# 13487                    1                          0

# %%
zero_zero_decimal_data = add_discount_percentage_col(one_zero_decimal_data)

outliers = check_for_outliers(one_zero_decimal_data)
outliers
# Out:
# Empty DataFrame
# Columns: [sku, name, desc, price, promo_price, price_decimal_count, promo_price_decimal_count, discount_percentage]
# Index: []

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     Some of the price or promo_price values here are incorrect.
# </div>

# %% [markdown]
# ## price_decimal_count = 0,  promo_price_decimal_count = 1

# %%
skus = products_temp[
    (products_temp.price_decimal_count == 0) &
    (products_temp.promo_price_decimal_count == 1)
].sku

zero_one_decimal_data = products_temp[products_temp.sku.isin(skus)].copy()
zero_one_decimal_data[['price', 'promo_price']] = zero_one_decimal_data[['price', 'promo_price']].astype('float')

corrupted_price_skus = test_price_greater_or_equal_to_promo_price(zero_one_decimal_data)
zero_one_decimal_data[zero_one_decimal_data.sku.isin(corrupted_price_skus)].head()
# Out:
# There are corrupted values in price which are less than their corresponding promo_price values.
# This respresents 80.43% of the data.
#          sku                                               name  \
# 1    APP0023                  Apple Mac Keyboard Keypad Spanish
# 2    APP0025                   Mighty Mouse Apple Mouse for Mac
# 3    APP0072      Apple Dock to USB Cable iPhone and iPod white
# 5    APP0073     Apple Composite AV Cable iPhone and iPod white
# 8  KIN0001-2  Mac memory Kingston 4GB (2x2GB) 667MHz DDR2 SO...
#
#                                                 desc  price  promo_price  \
# 1          USB ultrathin keyboard Apple Mac Spanish.   59.0      589.996
# 2                             mouse Apple USB cable.   59.0      569.898
# 3              IPhone dock and USB Cable Apple iPod.   25.0      229.997
# 5  IPhone and iPod AV Cable Dock to Composite Video.   45.0      420.003
# 8  RAM 4GB (2x2GB) Mac mini and iMac (2006/07) Ma...   74.0      669.904
#
#    price_decimal_count  promo_price_decimal_count
# 1                    0                          1
# 2                    0                          1
# 3                    0                          1
# 5                    0                          1
# 8                    0                          1

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     It appears that 80% of the promo_price values in our subset have the decimal point one place too far to the left.
#     <br>
#     <br>
#     Let's try to fix this and see if the test passes.
# </div>

# %%
''' 
First extract the skus of the promo_prices which passed the test to see if there is a 
difference between the format of their promo_price values and the values that didn't pass. 
'''
passing_skus = zero_one_decimal_data[zero_one_decimal_data.price >= zero_one_decimal_data.promo_price].sku

# %%
# Copy the data again to view the prices in string format
skus = products_temp[
    (products_temp.price_decimal_count == 0) &
    (products_temp.promo_price_decimal_count == 1)
].sku
zero_one_decimal_data = products_temp[products_temp.sku.isin(skus)].copy()

zero_one_decimal_data[zero_one_decimal_data.sku.isin(passing_skus)].head()
# Out:
#          sku                                               name  \
# 262  PAC0183  Apple MacBook Pro 133 "25GHz | 8GB RAM | 500GB...
# 297  WDT0139           Red 1TB WD 35 "Mac PC hard drive and NAS
# 306  SAN0014      SanDisk Cruzer Blade 16GB USB 2.0 Flash Drive
# 341  APP0416                       Apple iPod Touch 32GB Silver
# 342  APP0417                       Apple iPod Touch 32GB yellow
#
#                                                   desc price promo_price  \
# 262  Apple MacBook Pro 133 inches (MD101Y / A) with...  1319     1279.99
# 297  Western Digital hard drive designed for NAS 1T...    77      64.493
# 306       Compact flash drive 16GB USB 2.0 Mac and PC.     6        4.99
# 341   New generation iPod touch 5 32GB white / silver.   279      264.99
# 342           New 5 generation iPod touch 32GB yellow.   279      264.99
#
#      price_decimal_count  promo_price_decimal_count
# 262                    0                          1
# 297                    0                          1
# 306                    0                          1
# 341                    0                          1
# 342                    0                          1

# %%
'''
There is no pattern
Some of the promo_price values have 1, 2 or 3 digits after the decimal place
just like in the corrupted data.
'''
zero_one_decimal_data[zero_one_decimal_data.sku.isin(['GTE0012-A', 'SAN0014', 'WDT0139'])]
# Out:
#             sku                                           name  \
# 297     WDT0139       Red 1TB WD 35 "Mac PC hard drive and NAS
# 306     SAN0014  SanDisk Cruzer Blade 16GB USB 2.0 Flash Drive
# 1892  GTE0012-A    (Open) G-Tech G-DRIVE USB 3.0 Hard Disk 2TB
#
#                                                    desc price promo_price  \
# 297   Western Digital hard drive designed for NAS 1T...    77      64.493
# 306        Compact flash drive 16GB USB 2.0 Mac and PC.     6        4.99
# 1892  external hard drive G-Technology for Mac or PC...   235       169.9
#
#       price_decimal_count  promo_price_decimal_count
# 297                     0                          1
# 306                     0                          1
# 1892                    0                          1

# %%
'''
We're going to have to move the decimal point until the promo_price is less than or equal to the price
'''
# Copy the data again so the prices are back in str form
skus = products_temp[
    (products_temp.price_decimal_count == 0) &
    (products_temp.promo_price_decimal_count == 1)
].sku
zero_one_decimal_data = products_temp[products_temp.sku.isin(skus)].copy()

# Transform the price col to float
zero_one_decimal_data.price = zero_one_decimal_data.price.astype('float')

# %%
import math

def _insert_decimal_at_string_position(s, pos):
    '''Insert a decimal point at a given position in a string'''
    s = s.split('.')
    s = s[0] + s[1]
    s = s[:pos]+'.'+s[pos:]
    return s 

def _insert_decimal_in_promo_price(row, decimal_position = -2):
    '''
    If the euro value of the price is equal to the euro value of the promo_price, 
    set the promo_price equal to price and return it.
    This is because some promo_prices are slightly larger than their equivalent prices, such as: 
    price - promo_price
    12.95 - 12.99
    59.00 - 59.99 
    89.00 - 89.79
    549.00 - 550.33
    55.0	5.88	
    60.0	6.86	
    529.0	53.18
    
    Otherwise, keep moving the decimal point towards the start of the string until the promo_price is lower than the price.
    Then transform the string to a float and round it to two decimal places.
    '''
    
    while float(row.promo_price) > row.price:
        #print(row.price, row.promo_price, math.floor(row.price)), math.floor(float(row.promo_price))
        if math.floor(float(row.promo_price)) == math.floor(row.price):
            row.promo_price = row.price
            return row.promo_price
        else:
            row.promo_price = _insert_decimal_at_string_position(row.promo_price, decimal_position)
            decimal_position += -1
    #print("promo_price:", round(float(row.promo_price), 2))
    return round(float(row.promo_price), 2)


def transform_promo_price_to_float_wrt_price(df):
    df.promo_price = [_insert_decimal_in_promo_price(row) for index, row in df.iterrows()]
    return df

test_data = zero_one_decimal_data.copy() #[zero_one_decimal_data.sku.isin(['APP1482'])].copy()
test_data = transform_promo_price_to_float_wrt_price(test_data)
test_data
# Out:
#              sku                                               name  \
# 1        APP0023                  Apple Mac Keyboard Keypad Spanish
# 2        APP0025                   Mighty Mouse Apple Mouse for Mac
# 3        APP0072      Apple Dock to USB Cable iPhone and iPod white
# 5        APP0073     Apple Composite AV Cable iPhone and iPod white
# 8      KIN0001-2  Mac memory Kingston 4GB (2x2GB) 667MHz DDR2 SO...
# ...          ...                                                ...
# 19283    AP20468       Like new - Apple iPhone Black Lightning Dock
# 19285    AP20470  Like new - Apple Thunderbolt to Gigabit Ethern...
# 19288    AP20649  Like new - Apple Leather Case iPhone Case 8/7 ...
# 19295    AP20471          Apple Thunderbolt to FireWire 800 adapter
# 19303    AP20472           Like new - Apple charging cable 2m USB-C
#
#                                                     desc  price  promo_price  \
# 1              USB ultrathin keyboard Apple Mac Spanish.   59.0        59.00
# 2                                 mouse Apple USB cable.   59.0        56.99
# 3                  IPhone dock and USB Cable Apple iPod.   25.0        23.00
# 5      IPhone and iPod AV Cable Dock to Composite Video.   45.0        42.00
# 8      RAM 4GB (2x2GB) Mac mini and iMac (2006/07) Ma...   74.0        66.99
# ...                                                  ...    ...          ...
# 19283  Support base and refitted with dock connector ...   59.0        44.00
# 19285  Refurbished Mac adapter Thunderbolt to Gigabit...   35.0        28.00
# 19288  Reconditioned sleeve leather and microfiber Ap...   55.0        42.00
# 19295  Reconditioned connection adapter Thunderbolt t...   35.0        28.00
# 19303     Apple USB-C Cable 2 meters Refurbished MacBook   25.0        20.00
#
#        price_decimal_count  promo_price_decimal_count
# 1                        0                          1
# 2                        0                          1
# 3                        0                          1
# 5                        0                          1
# 8                        0                          1
# ...                    ...                        ...
# 19283                    0                          1
# 19285                    0                          1
# 19288                    0                          1
# 19295                    0                          1
# 19303                    0                          1
#
# [1104 rows x 7 columns]

# %%
corrupted_price_skus = test_price_greater_or_equal_to_promo_price(test_data)
# Out:
# All of the price values are greater or equal to the corresponding promo_price values.

# %%
test_data = add_discount_percentage_col(test_data)

outliers = check_for_outliers(test_data)
outliers
# Out:
#              sku                                               name  \
# 560      KIN0078                       Kingston V300 SSD Disk 120GB
# 1301     LAC0134                       LaCie 6TB 2big Thunderbolt 2
# 2884     APP1104                  Apple iPod Shuffle 2GB Gray Space
# 2888     APP1105                        Apple iPod Shuffle 2GB Pink
# 2889     APP1106                        Apple iPod Shuffle 2GB Blue
# 2890     APP1102                      Apple iPod Shuffle 2GB Silver
# 2891     APP1103                        Apple iPod Shuffle 2GB Gold
# 11770    APP1482                           Apple iPhone 64GB Silver
# 11771    APP1483                             Apple iPhone 64GB Gold
# 11772    APP1484                        Apple iPhone 64GB Rose Gold
# 13316    APP1750                 Apple iPad Air 2 Wi-Fi 32GB Dorado
# 13318    APP1749                 Apple iPad Air 2 Wi-Fi 32GB Silver
# 13329    APP1758                Apple iPad Mini 4 Wi-Fi 32GB Silver
# 13330    APP1759                  Apple iPad Mini 4 Wi-Fi 32GB Gold
# 15140    EIZ0024  Eizo FlexScan EV2736W Monitor 27 "QHD DP pivot...
# 15248  APP1659-A              Open - 32GB Apple iPhone 6s Rose Gold
# 16069    AP20183         Like new - Apple iPhone 6s Plus 128GB Gold
# 17217    AP20124        Like new - Apple iPad Camera Connection Kit
# 17218    AP20125             Like new - Apple Dock Connector to VGA
# 18956    CAV0007                    Cavus Play 1 Black Wall Support
# 18957    CAV0008                    Cavus Support Wall Play 1 White
# 18962    CAV0009              Cavus Foot Support Sonos Play 1 Black
# 18963    CAV0010              Cavus Foot Support Sonos Play 1 White
#
#                                                     desc  price  promo_price  \
# 560            SSD 120GB SATA Hard Drive Mac and PC III.   60.0         6.86
# 1301      Dual-drive RAID box for Mac 6TB Thunderbolt 2.  529.0        53.18
# 2884       Music player iPod Shuffle 2GB and small size.   55.0         5.88
# 2888       Music player iPod Shuffle 2GB and small size.   55.0         5.88
# 2889       Music player iPod Shuffle 2GB and small size.   55.0         5.88
# 2890       Music player iPod Shuffle 2GB and small size.   55.0         5.88
# 2891       Music player iPod Shuffle 2GB and small size.   55.0         5.88
# 11770       New iPhone SE with 4-inch screen 64 free GB.  549.0        55.03
# 11771       New iPhone SE with 4-inch screen 64 free GB.  549.0        55.03
# 11772       New iPhone SE with 4-inch screen 64 free GB.  549.0        55.03
# 13316           New iPad Air 2 Wi-Fi 32GB (MNV72TY / A).  429.0        43.28
# 13318     New Apple iPad Air 2 Wi-Fi 32GB (MNV62TY / A).  429.0        43.28
# 13329                      Apple iPad Mini 4 32GB Wi-Fi.  429.0        43.28
# 13330                      Apple iPad Mini 4 32GB Wi-Fi.  429.0        43.28
# 15140  27-inch monitor with slim frame and adjustable...  629.0        65.00
# 15248                            New iPhone 6S 16GB Free  529.0        60.03
# 16069  Apple iPhone 6s Plus 128GB Reconditioned Free ...  749.0        75.03
# 17217  Reconditioned Adapter Compatible digital camer...   35.0         4.99
# 17218                          Dock Connector to VGA IOS   35.0         5.99
# 18956                   Support for speaker Play 1 Sonos   29.0         3.51
# 18957                   Support for speaker Play 1 Sonos   29.0         3.51
# 18962               Floor stand for Speaker Sonos Play 1   59.0         7.14
# 18963               Floor stand for Speaker Sonos Play 1   59.0         7.14
#
#        price_decimal_count  promo_price_decimal_count  discount_percentage
# 560                      0                          1            88.566667
# 1301                     0                          1            89.947070
# 2884                     0                          1            89.309091
# 2888                     0                          1            89.309091
# 2889                     0                          1            89.309091
# 2890                     0                          1            89.309091
# 2891                     0                          1            89.309091
# 11770                    0                          1            89.976321
# 11771                    0                          1            89.976321
# 11772                    0                          1            89.976321
# 13316                    0                          1            89.911422
# 13318                    0                          1            89.911422
# 13329                    0                          1            89.911422
# 13330                    0                          1            89.911422
# 15140                    0                          1            89.666137
# 15248                    0                          1            88.652174
# 16069                    0                          1            89.982644
# 17217                    0                          1            85.742857
# 17218                    0                          1            82.885714
# 18956                    0                          1            87.896552
# 18957                    0                          1            87.896552
# 18962                    0                          1            87.898305
# 18963                    0                          1            87.898305

# %%
''' Let's check some of the values which do not seem to match. '''

orderlines_clean = pd.read_csv('../../data/orderlines_clean.csv')
orderlines_clean[orderlines_clean.sku=="APP1749"]
# Out:
#             id  order_id  product_quantity      sku  unit_price  \
# 110    1119301    299631                 1  APP1749      429.00
# 627    1120315    300140                 1  APP1749      429.00
# 656    1120359    300162                 1  APP1749      429.00
# 667    1120375    300172                 1  APP1749      429.00
# 678    1120398    300181                 1  APP1749      429.00
# 1755   1122711    301185                 1  APP1749      429.00
# 2077   1123350    301487                 1  APP1749      429.00
# 3675   1130717    302898                 1  APP1749      429.00
# 4550   1132509    303757                 1  APP1749      411.99
# 4590   1132579    303802                 1  APP1749      429.00
# 4627   1132641    303840                 1  APP1749      411.99
# 5277   1134228    304458                 1  APP1749      411.99
# 5407   1134528    304574                 1  APP1749      411.99
# 5534   1134790    304679                 2  APP1749      411.99
# 5767   1135256    304881                 1  APP1749      411.99
# 6446   1136597    305483                 1  APP1749      411.99
# 6469   1136644    305509                 1  APP1749      411.99
# 7482   1138889    306410                 1  APP1749      411.99
# 7617   1139232    306531                 1  APP1749      411.99
# 7766   1139560    306668                 1  APP1749      411.99
# 8019   1140052    306881                 1  APP1749      411.99
# 8522   1141138    307331                 1  APP1749      411.99
# 11201  1146612    309695                 1  APP1749      411.99
# 11634  1147410    310079                 1  APP1749      411.99
# 11888  1147930    310311                 1  APP1749      411.99
# 12621  1149575    310697                 1  APP1749      411.99
# 13672  1151764    310296                 2  APP1749      411.99
# 14056  1152555    312124                 1  APP1749      411.99
# 14412  1153252    312410                10  APP1749      411.99
# 15054  1154510    312935                 1  APP1749      411.99
# 15165  1154731    313026                 1  APP1749      411.99
# 15242  1154871    313081                 1  APP1749      411.99
# 16594  1157731    314196                 1  APP1749      411.99
# 16976  1158523    314520                 1  APP1749      411.99
# 17503  1159606    314962                 1  APP1749      411.99
# 18760  1162041    316072                 1  APP1749      411.99
# 18838  1162183    315617                 1  APP1749      411.99
# 19357  1163185    316594                 1  APP1749      411.99
# 20341  1165598    317518                 1  APP1749      411.99
# 20942  1167001    318040                 1  APP1749      411.99
# 21181  1167517    318242                 1  APP1749      411.99
# 22154  1169469    319070                 1  APP1749      411.99
# 23345  1171631    320086                 1  APP1749      429.00
# 23657  1172149    320349                 1  APP1749      429.00
# 24351  1173555    317761                 1  APP1749      412.99
# 25938  1176535    322342                 1  APP1749      429.00
# 27689  1179836    323874                 1  APP1749      429.00
# 27691  1179839    323876                 1  APP1749      429.00
# 28315  1181157    324393                 1  APP1749      429.00
# 29482  1183312    325325                 1  APP1749      429.00
# 30550  1185240    326221                 1  APP1749      429.00
# 31672  1187379    327206                 1  APP1749      429.00
# 31892  1187803    327403                 1  APP1749      429.00
# 32033  1188082    327513                 1  APP1749      429.00
# 33488  1190919    328812                 1  APP1749      429.00
# 33548  1191028    328863                 1  APP1749      429.00
# 33691  1191281    328991                 1  APP1749      429.00
# 34589  1192811    329737                 1  APP1749      429.00
# 34693  1193002    329827                 1  APP1749      429.00
#
#                       date short
# 110    2017-01-01 11:43:38   APP
# 627    2017-01-02 00:13:43   APP
# 656    2017-01-02 00:30:48   APP
# 667    2017-01-02 00:47:02   APP
# 678    2017-01-02 01:01:13   APP
# 1755   2017-01-02 23:56:13   APP
# 2077   2017-01-03 12:01:11   APP
# 3675   2017-01-05 07:23:18   APP
# 4550   2017-01-06 19:10:26   APP
# 4590   2017-01-06 20:43:48   APP
# 4627   2017-01-06 21:35:38   APP
# 5277   2017-01-07 20:36:16   APP
# 5407   2017-01-08 00:27:59   APP
# 5534   2017-01-08 11:09:55   APP
# 5767   2017-01-08 18:06:14   APP
# 6446   2017-01-09 10:00:21   APP
# 6469   2017-01-09 10:17:54   APP
# 7482   2017-01-10 12:00:47   APP
# 7617   2017-01-10 14:33:31   APP
# 7766   2017-01-10 18:10:39   APP
# 8019   2017-01-10 22:33:02   APP
# 8522   2017-01-11 15:16:48   APP
# 11201  2017-01-15 12:16:26   APP
# 11634  2017-01-15 23:55:32   APP
# 11888  2017-01-16 11:34:32   APP
# 12621  2017-01-17 13:04:53   APP
# 13672  2017-01-18 20:16:31   APP
# 14056  2017-01-19 15:33:11   APP
# 14412  2017-01-20 10:30:42   APP
# 15054  2017-01-21 15:57:43   APP
# 15165  2017-01-21 21:35:24   APP
# 15242  2017-01-22 01:35:38   APP
# 16594  2017-01-24 12:00:16   APP
# 16976  2017-01-25 00:50:24   APP
# 17503  2017-01-26 00:30:24   APP
# 18760  2017-01-27 20:05:15   APP
# 18838  2017-01-27 23:03:17   APP
# 19357  2017-01-29 11:14:27   APP
# 20341  2017-01-30 14:21:31   APP
# 20942  2017-01-31 10:16:54   APP
# 21181  2017-01-31 15:08:10   APP
# 22154  2017-02-02 07:30:55   APP
# 23345  2017-02-05 12:05:02   APP
# 23657  2017-02-06 09:29:14   APP
# 24351  2017-02-07 15:53:31   APP
# 25938  2017-02-10 16:37:14   APP
# 27689  2017-02-14 00:42:12   APP
# 27691  2017-02-14 00:50:44   APP
# 28315  2017-02-15 08:24:00   APP
# 29482  2017-02-16 17:06:35   APP
# 30550  2017-02-19 12:56:01   APP
# 31672  2017-02-21 16:10:31   APP
# 31892  2017-02-22 00:14:39   APP
# 32033  2017-02-22 11:29:35   APP
# 33488  2017-02-25 09:03:24   APP
# 33548  2017-02-25 12:51:42   APP
# 33691  2017-02-25 21:03:25   APP
# 34589  2017-02-27 12:38:06   APP
# 34693  2017-02-27 14:39:50   APP

# %% [markdown]
# <div class="alert alert-bloc alert-danger">
#     sku=="APP1749"
#     <br><br>
#     Clearly the promo_price values are incorrect.
#     <br><br>
#     products.price == 429.00 is correct.
#     products.promo_price == 43.28 is probably supposed to be 432.8 but either way it is correct.
#     <br><br>
#     As we can see above, the unit_price varies over time. Clearly varying discounts have been applied at different times. This is exactly what we want to analyse.
#     <br><br>
#     We will have to ignore the products.promo_price values.
#     <br>
#     The products.price and orderlines.unit_price values will have to be merged and compared.
#     <br>
#     The price cleaning functions above can be reused but it might make more sense to use the discount percentage to compare the values when adjusting the decimal point position.
# </div>
